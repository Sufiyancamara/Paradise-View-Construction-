# %%
import pandas as pd
import numpy as np

# %%
bricks = pd.read_csv('ParadiseView/out/df_ffBrickMolding.csv')

# %%
const = pd.read_csv('ParadiseView/out/firstFloor_const.csv')

# %%
bricks
# Out:
#                       item  quantity  unit_cost  total_cost        date  \
# 0        $100 Transfer Fee       1.0      250.0       250.0  2022-03-27
# 1            Cutting Trees       1.0     5000.0      5000.0  2022-04-03
# 2            Clearing Plot       1.0     2500.0      2500.0  2022-04-03
# 3      $1,000 Transfer Fee       1.0     1000.0      1000.0  2022-04-16
# 4                  Cement       75.0      320.0     24000.0  2022-04-18
# 5         Cement Transport      75.0       20.0      1500.0  2022-04-18
# 6             Wheelbarrow        1.0     3000.0      3000.0  2022-04-18
# 7           50m Hose/Pipe        1.0     1400.0      1400.0  2022-04-18
# 8            Small Bucket        2.0      100.0       200.0  2022-04-18
# 9            Big Sand Trip       2.0     8000.0     16000.0  2022-04-18
# 10             Small Tank        1.0     1600.0      1600.0  2022-04-18
# 11         Cement Watchman       1.0      500.0       500.0  2022-04-18
# ...

# %%
const
# Out:
#                                    item  quantity  unit_cost  total_cost  \
# 0                           1 by 2 wood        25      100.0      2500.0
# 1                           Wooden Pake        15       35.0       500.0
# 2                    3 Inches Nale(kg)          2      100.0       200.0
# 3           2 and half Inches Nale(kg)          2      100.0       200.0
# 4             Materials Transportation          1      500.0       500.0
# ..                                  ...       ...        ...         ...
# 337  Returning Roof Concrete Materials          1     8500.0      8500.0
# 338                    Cement Transport        25       20.0       500.0
# 339                             Cemennt        38      415.0     15770.0
# 340                   Cemennt Transport        38       30.0      1140.0
# 341                   Cemennt Transport        38       30.0      1140.0
#
#            date     sub_category   category  exchange_rate
# ...

# %%
floorOne = pd.concat([bricks, const], axis=0, ignore_index=True)

# %%
print(floorOne.to_string())
# Out:
#                                     item  quantity  unit_cost  total_cost        date     sub_category   category  exchange_rate
# 0                      $100 Transfer Fee       1.0      250.0       250.0  2022-03-27    Brick Molding  1st Floor          50.00
# 1                          Cutting Trees       1.0     5000.0      5000.0  2022-04-03    Brick Molding  1st Floor          50.00
# 2                          Clearing Plot       1.0     2500.0      2500.0  2022-04-03    Brick Molding  1st Floor          50.00
# 3                    $1,000 Transfer Fee       1.0     1000.0      1000.0  2022-04-16    Brick Molding  1st Floor          50.00
# 4                                Cement       75.0      320.0     24000.0  2022-04-18    Brick Molding  1st Floor          50.00
# 5                       Cement Transport      75.0       20.0      1500.0  2022-04-18    Brick Molding  1st Floor          50.00
# ...

# %%
floorOne.to_csv('ParadiseView/clean/floorOne.csv', index=False)
