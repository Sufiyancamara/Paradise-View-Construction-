# %%
import numpy as np
import pandas as pd

# %%
cost_data = pd.read_excel("ParadiseView/Paradise View Expenditures 4.xlsx")

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cost_columns = np.array(['item', 'cost_D', 'cost_$', 'Date'])

# %%
cost_columns
# Out:
# array(['item', 'cost_D', 'cost_$', 'Date'], dtype='<U6')

# %%
df_cost = pd.read_excel("ParadiseView/Paradise View Expenditures 4.xlsx", skiprows=10, nrows=12)

# %%
df_cost
# Out:
#                    ITEM  COST(D)     COST($)        DATE
# 0       Physical Plan 1      1500   30.612245 2019-08-09
# 1       Physical Plan 2      1000   20.408163 2019-12-17
# 2          MoneyTra Fee       490   10.000000 2020-02-06
# 3       Physical Plan 2      2000   40.816327 2020-02-07
# 4            GTBank Fee      5000  102.040816 2020-02-07
# 5           Gas for Car       500   10.204082 2020-02-07
# 6   Chief Area Council       2000   40.816327 2020-02-10
# 7           Gas for Car       500   10.204082 2020-02-10
# 8     Lady Filled Forms       400    8.163265 2020-02-10
# 9         Sukuta Alkalo      1500   30.612245 2020-02-11
# 10                  Gas       100    2.040816 2020-02-11

# %%
df_cost.columns
# Out:
# Index(['ITEM', 'COST(D) ', 'COST($) ', 'DATE'], dtype='str')

# %%
df_cost.rename(columns={"COST(D) ": "cost_dalasi", "COST($) ": "cost_dollar"}, inplace=True)

# %%
df_cost.columns = df_cost.columns.str.lower()

# %%
df_cost
# Out:
#                    item  cost_dalasi  cost_dollar       date
# 0       Physical Plan 1         1500    30.612245 2019-08-09
# 1       Physical Plan 2         1000    20.408163 2019-12-17
# 2          MoneyTra Fee          490    10.000000 2020-02-06
# 3       Physical Plan 2         2000    40.816327 2020-02-07
# 4            GTBank Fee         5000   102.040816 2020-02-07
# 5           Gas for Car          500    10.204082 2020-02-07
# 6   Chief Area Council          2000    40.816327 2020-02-10
# 7           Gas for Car          500    10.204082 2020-02-10
# 8     Lady Filled Forms          400     8.163265 2020-02-10
# 9         Sukuta Alkalo         1500    30.612245 2020-02-11
# 10                  Gas          100     2.040816 2020-02-11

# %%
df_cost['date'] = pd.to_datetime(df_cost['date'])

# %%
df_cost
# Out:
#                    item  cost_dalasi  cost_dollar       date
# 0       Physical Plan 1         1500    30.612245 2019-08-09
# 1       Physical Plan 2         1000    20.408163 2019-12-17
# 2          MoneyTra Fee          490    10.000000 2020-02-06
# 3       Physical Plan 2         2000    40.816327 2020-02-07
# 4            GTBank Fee         5000   102.040816 2020-02-07
# 5           Gas for Car          500    10.204082 2020-02-07
# 6   Chief Area Council          2000    40.816327 2020-02-10
# 7           Gas for Car          500    10.204082 2020-02-10
# 8     Lady Filled Forms          400     8.163265 2020-02-10
# 9         Sukuta Alkalo         1500    30.612245 2020-02-11
# 10                  Gas          100     2.040816 2020-02-11

# %%
df_cost['date'] = df_cost['date'].dt.strftime('%m/%d/%Y')

# %%
df_cost
# Out:
#                    item  cost_dalasi  cost_dollar        date
# 0       Physical Plan 1         1500    30.612245  08/09/2019
# 1       Physical Plan 2         1000    20.408163  12/17/2019
# 2          MoneyTra Fee          490    10.000000  02/06/2020
# 3       Physical Plan 2         2000    40.816327  02/07/2020
# 4            GTBank Fee         5000   102.040816  02/07/2020
# 5           Gas for Car          500    10.204082  02/07/2020
# 6   Chief Area Council          2000    40.816327  02/10/2020
# 7           Gas for Car          500    10.204082  02/10/2020
# 8     Lady Filled Forms          400     8.163265  02/10/2020
# 9         Sukuta Alkalo         1500    30.612245  02/11/2020
# 10                  Gas          100     2.040816  02/11/2020

# %%
df_costDalasiDollar = df_cost

# %%
df_costClean = df_cost.drop('cost_dollar', axis=1)

# %%
df_costClean
# Out:
#                    item  cost_dalasi        date
# 0       Physical Plan 1         1500  08/09/2019
# 1       Physical Plan 2         1000  12/17/2019
# 2          MoneyTra Fee          490  02/06/2020
# 3       Physical Plan 2         2000  02/07/2020
# 4            GTBank Fee         5000  02/07/2020
# 5           Gas for Car          500  02/07/2020
# 6   Chief Area Council          2000  02/10/2020
# 7           Gas for Car          500  02/10/2020
# 8     Lady Filled Forms          400  02/10/2020
# 9         Sukuta Alkalo         1500  02/11/2020
# 10                  Gas          100  02/11/2020

# %%
df_costClean.rename(columns={'cost_dalasi': 'cost'}, inplace=True)

# %%
df_costClean
# Out:
#                    item  cost        date
# 0       Physical Plan 1  1500  08/09/2019
# 1       Physical Plan 2  1000  12/17/2019
# 2          MoneyTra Fee   490  02/06/2020
# 3       Physical Plan 2  2000  02/07/2020
# 4            GTBank Fee  5000  02/07/2020
# 5           Gas for Car   500  02/07/2020
# 6   Chief Area Council   2000  02/10/2020
# 7           Gas for Car   500  02/10/2020
# 8     Lady Filled Forms   400  02/10/2020
# 9         Sukuta Alkalo  1500  02/11/2020
# 10                  Gas   100  02/11/2020

# %%
df_costClean.to_csv('ParadiseView/out/costClean1.csv')

# %%
# %timeit df_costClean.to_csv('ParadiseView/out/costClean1.csv')
# Out:
# 5.86 ms ± 133 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
skiprows = [0,1,2,3,6,7,8,9,10,22,23,24,25]

# %%
cost_data2 = pd.read_excel("ParadiseView/Paradise View Expenditures 4.xlsx", skiprows=skiprows)

# %%
cost_data2
# Out:
#                              ITEM  COST(D)      COST($)        DATE
# 0   Paradise View Plot: 20m x 25m   750000  15000.000000 2019-08-03
# 1                 Physical Plan 1     1500     30.612245 2019-08-09
# 2                 Physical Plan 2     1000     20.408163 2019-12-17
# 3                    MoneyTra Fee      490     10.000000 2020-02-06
# 4                 Physical Plan 2     2000     40.816327 2020-02-07
# 5                      GTBank Fee     5000    102.040816 2020-02-07
# 6                     Gas for Car      500     10.204082 2020-02-07
# 7             Chief Area Council      2000     40.816327 2020-02-10
# 8                     Gas for Car      500     10.204082 2020-02-10
# 9               Lady Filled Forms      400      8.163265 2020-02-10
# 10                  Sukuta Alkalo     1500     30.612245 2020-02-11
# 11                            Gas      100      2.040816 2020-02-11

# %%
cost_data2.rename(columns={'COST(D)': 'cost_dalasi', 'COST($) ': 'cost_dollar'}, inplace=True)

# %%
cost_data2
# Out:
#                              ITEM  cost_dalasi   cost_dollar       DATE
# 0   Paradise View Plot: 20m x 25m       750000  15000.000000 2019-08-03
# 1                 Physical Plan 1         1500     30.612245 2019-08-09
# 2                 Physical Plan 2         1000     20.408163 2019-12-17
# 3                    MoneyTra Fee          490     10.000000 2020-02-06
# 4                 Physical Plan 2         2000     40.816327 2020-02-07
# 5                      GTBank Fee         5000    102.040816 2020-02-07
# 6                     Gas for Car          500     10.204082 2020-02-07
# 7             Chief Area Council          2000     40.816327 2020-02-10
# 8                     Gas for Car          500     10.204082 2020-02-10
# 9               Lady Filled Forms          400      8.163265 2020-02-10
# 10                  Sukuta Alkalo         1500     30.612245 2020-02-11
# 11                            Gas          100      2.040816 2020-02-11

# %%
cost_data2.columns = cost_data2.columns.str.lower()

# %%
cost_data2
# Out:
#                              item  cost_dalasi   cost_dollar       date
# 0   Paradise View Plot: 20m x 25m       750000  15000.000000 2019-08-03
# 1                 Physical Plan 1         1500     30.612245 2019-08-09
# 2                 Physical Plan 2         1000     20.408163 2019-12-17
# 3                    MoneyTra Fee          490     10.000000 2020-02-06
# 4                 Physical Plan 2         2000     40.816327 2020-02-07
# 5                      GTBank Fee         5000    102.040816 2020-02-07
# 6                     Gas for Car          500     10.204082 2020-02-07
# 7             Chief Area Council          2000     40.816327 2020-02-10
# 8                     Gas for Car          500     10.204082 2020-02-10
# 9               Lady Filled Forms          400      8.163265 2020-02-10
# 10                  Sukuta Alkalo         1500     30.612245 2020-02-11
# 11                            Gas          100      2.040816 2020-02-11

# %%
cost_data2['date'] = pd.to_datetime(cost_data2['date'])

# %%
cost_data2['date'] = cost_data2['date'].dt.strftime("%m/%d/%Y")

# %%
cost_data2
# Out:
#                              item  cost_dalasi   cost_dollar        date
# 0   Paradise View Plot: 20m x 25m       750000  15000.000000  08/03/2019
# 1                 Physical Plan 1         1500     30.612245  08/09/2019
# 2                 Physical Plan 2         1000     20.408163  12/17/2019
# 3                    MoneyTra Fee          490     10.000000  02/06/2020
# 4                 Physical Plan 2         2000     40.816327  02/07/2020
# 5                      GTBank Fee         5000    102.040816  02/07/2020
# 6                     Gas for Car          500     10.204082  02/07/2020
# 7             Chief Area Council          2000     40.816327  02/10/2020
# 8                     Gas for Car          500     10.204082  02/10/2020
# 9               Lady Filled Forms          400      8.163265  02/10/2020
# 10                  Sukuta Alkalo         1500     30.612245  02/11/2020
# 11                            Gas          100      2.040816  02/11/2020

# %%
df_cost = cost_data2.drop(columns='cost_dollar')

# %%
df_cost
# Out:
#                              item  cost_dalasi        date
# 0   Paradise View Plot: 20m x 25m       750000  08/03/2019
# 1                 Physical Plan 1         1500  08/09/2019
# 2                 Physical Plan 2         1000  12/17/2019
# 3                    MoneyTra Fee          490  02/06/2020
# 4                 Physical Plan 2         2000  02/07/2020
# 5                      GTBank Fee         5000  02/07/2020
# 6                     Gas for Car          500  02/07/2020
# 7             Chief Area Council          2000  02/10/2020
# 8                     Gas for Car          500  02/10/2020
# 9               Lady Filled Forms          400  02/10/2020
# 10                  Sukuta Alkalo         1500  02/11/2020
# 11                            Gas          100  02/11/2020

# %%
df_costClean = df_cost.rename(columns={'cost_dalasi': 'cost'})

# %%
df_costClean
# Out:
#                              item    cost        date
# 0   Paradise View Plot: 20m x 25m  750000  08/03/2019
# 1                 Physical Plan 1    1500  08/09/2019
# 2                 Physical Plan 2    1000  12/17/2019
# 3                    MoneyTra Fee     490  02/06/2020
# 4                 Physical Plan 2    2000  02/07/2020
# 5                      GTBank Fee    5000  02/07/2020
# 6                     Gas for Car     500  02/07/2020
# 7             Chief Area Council     2000  02/10/2020
# 8                     Gas for Car     500  02/10/2020
# 9               Lady Filled Forms     400  02/10/2020
# 10                  Sukuta Alkalo    1500  02/11/2020
# 11                            Gas     100  02/11/2020

# %%
df_costClean.to_csv('ParadiseView/out/df_cost_clean.csv', index=False)

# %%
df2 = pd.read_csv('ParadiseView/out/df_cost_clean.csv')

# %%
df2
# Out:
#                              item    cost        date
# 0   Paradise View Plot: 20m x 25m  750000  08/03/2019
# 1                 Physical Plan 1    1500  08/09/2019
# 2                 Physical Plan 2    1000  12/17/2019
# 3                    MoneyTra Fee     490  02/06/2020
# 4                 Physical Plan 2    2000  02/07/2020
# 5                      GTBank Fee    5000  02/07/2020
# 6                     Gas for Car     500  02/07/2020
# 7             Chief Area Council     2000  02/10/2020
# 8                     Gas for Car     500  02/10/2020
# 9               Lady Filled Forms     400  02/10/2020
# 10                  Sukuta Alkalo    1500  02/11/2020
# 11                            Gas     100  02/11/2020

# %%
df_fencing = pd.read_excel("ParadiseView/Paradise View Expenditures 6.xlsx", skiprows=6, sheet_name="Fencing")

# %%
df_fencing
# Out:
#                       ITEM          QUANTITY  UNIT PRICE(D)  \
# 0            Cutting Trees                  1         10000
# 1         Big Trip of Sand                  1          7500
# 2       Small Trip of Sand                  1          4000
# 3                  Cement                  40           285
# 4        Cement Transport                   1           600
# 5       Wheelbarrow Rental                  1           200
# 6           Molding Bricks               1370             5
# 7       Water for Molding                   1          1000
# 8       Gas for Transport                   1           450
# 9           Police Ticket                   1           200
# 10        Trip of Pebbles                   1          3500
# 11                 Cement                  25           285
# 12       Cement Transport                  25            15
# 13     Papa Jara Transport                  1           600
# 14      Gas for Transport                   1           200
# ...

# %%
df_fencing = df_fencing.drop(df_fencing.iloc[40:].index)

# %%
df_fencing
# Out:
#                       ITEM QUANTITY  UNIT PRICE(D) TOTAL COST(D)    TOTAL($)  \
# 0            Cutting Trees         1         10000         10000  204.081633
# 1         Big Trip of Sand         1          7500          7500  153.061224
# 2       Small Trip of Sand         1          4000          4000   81.632653
# 3                  Cement         40           285         11400  232.653061
# 4        Cement Transport          1           600           600   12.244898
# 5       Wheelbarrow Rental         1           200           200    4.081633
# 6           Molding Bricks      1370             5          6850  139.795918
# 7       Water for Molding          1          1000          1000   20.408163
# 8       Gas for Transport          1           450           450    9.183673
# 9           Police Ticket          1           200           200    4.081633
# 10        Trip of Pebbles          1          3500          3500   71.428571
# ...

# %%
df_fencing = df_fencing.drop(df_fencing.iloc[:, 6:], axis=1)

# %%
df_fencing
# Out:
#                       ITEM QUANTITY  UNIT PRICE(D) TOTAL COST(D)    TOTAL($)  \
# 0            Cutting Trees         1         10000         10000  204.081633
# 1         Big Trip of Sand         1          7500          7500  153.061224
# 2       Small Trip of Sand         1          4000          4000   81.632653
# 3                  Cement         40           285         11400  232.653061
# 4        Cement Transport          1           600           600   12.244898
# 5       Wheelbarrow Rental         1           200           200    4.081633
# 6           Molding Bricks      1370             5          6850  139.795918
# 7       Water for Molding          1          1000          1000   20.408163
# 8       Gas for Transport          1           450           450    9.183673
# 9           Police Ticket          1           200           200    4.081633
# 10        Trip of Pebbles          1          3500          3500   71.428571
# ...

# %%
df_fencing.iloc[25:26, 1:2] = 4

# %%
df_fencing.iloc[15:16, 1:2] = 1

# %%
df_fencing
# Out:
#                       ITEM QUANTITY  UNIT PRICE(D) TOTAL COST(D)    TOTAL($)  \
# 0            Cutting Trees         1         10000         10000  204.081633
# 1         Big Trip of Sand         1          7500          7500  153.061224
# 2       Small Trip of Sand         1          4000          4000   81.632653
# 3                  Cement         40           285         11400  232.653061
# 4        Cement Transport          1           600           600   12.244898
# 5       Wheelbarrow Rental         1           200           200    4.081633
# 6           Molding Bricks      1370             5          6850  139.795918
# 7       Water for Molding          1          1000          1000   20.408163
# 8       Gas for Transport          1           450           450    9.183673
# 9           Police Ticket          1           200           200    4.081633
# 10        Trip of Pebbles          1          3500          3500   71.428571
# ...

# %%
df_fencing.dropna(inplace=True)

# %%
df_fencing
# Out:
#                       ITEM QUANTITY  UNIT PRICE(D) TOTAL COST(D)    TOTAL($)  \
# 0            Cutting Trees         1         10000         10000  204.081633
# 1         Big Trip of Sand         1          7500          7500  153.061224
# 2       Small Trip of Sand         1          4000          4000   81.632653
# 3                  Cement         40           285         11400  232.653061
# 4        Cement Transport          1           600           600   12.244898
# 5       Wheelbarrow Rental         1           200           200    4.081633
# 6           Molding Bricks      1370             5          6850  139.795918
# 7       Water for Molding          1          1000          1000   20.408163
# 8       Gas for Transport          1           450           450    9.183673
# 9           Police Ticket          1           200           200    4.081633
# 10        Trip of Pebbles          1          3500          3500   71.428571
# ...

# %%
df_fencing.columns = df_fencing.columns.str.lower()

# %%
df_fencing
# Out:
#                       item quantity  unit price(d) total cost(d)    total($)  \
# 0            Cutting Trees         1         10000         10000  204.081633
# 1         Big Trip of Sand         1          7500          7500  153.061224
# 2       Small Trip of Sand         1          4000          4000   81.632653
# 3                  Cement         40           285         11400  232.653061
# 4        Cement Transport          1           600           600   12.244898
# 5       Wheelbarrow Rental         1           200           200    4.081633
# 6           Molding Bricks      1370             5          6850  139.795918
# 7       Water for Molding          1          1000          1000   20.408163
# 8       Gas for Transport          1           450           450    9.183673
# 9           Police Ticket          1           200           200    4.081633
# 10        Trip of Pebbles          1          3500          3500   71.428571
# ...

# %%
df_fencing.columns
# Out:
# Index(['item', 'quantity ', 'unit price(d)', 'total cost(d)', 'total($)',
#        'date'],
#       dtype='str')

# %%
df_fencing.rename(columns={'unit price(d)': 'unit_cost', 'total cost(d)': 'total_cost', 'total($)': 'total_dollar'}, inplace=True)

# %%
df_fencing
# Out:
#                       item quantity  unit_cost total_cost  total_dollar  \
# 0            Cutting Trees         1     10000      10000    204.081633
# 1         Big Trip of Sand         1      7500       7500    153.061224
# 2       Small Trip of Sand         1      4000       4000     81.632653
# 3                  Cement         40       285      11400    232.653061
# 4        Cement Transport          1       600        600     12.244898
# 5       Wheelbarrow Rental         1       200        200      4.081633
# 6           Molding Bricks      1370         5       6850    139.795918
# 7       Water for Molding          1      1000       1000     20.408163
# 8       Gas for Transport          1       450        450      9.183673
# 9           Police Ticket          1       200        200      4.081633
# 10        Trip of Pebbles          1      3500       3500     71.428571
# 11                 Cement         25       285       7125    145.408163
# ...

# %%
df_fencing['date'] = df_fencing['date'].dt.strftime('%m/%d/%Y')

# %%
df_fencing
# Out:
#                       item quantity  unit_cost total_cost  total_dollar  \
# 0            Cutting Trees         1     10000      10000    204.081633
# 1         Big Trip of Sand         1      7500       7500    153.061224
# 2       Small Trip of Sand         1      4000       4000     81.632653
# 3                  Cement         40       285      11400    232.653061
# 4        Cement Transport          1       600        600     12.244898
# 5       Wheelbarrow Rental         1       200        200      4.081633
# 6           Molding Bricks      1370         5       6850    139.795918
# 7       Water for Molding          1      1000       1000     20.408163
# 8       Gas for Transport          1       450        450      9.183673
# 9           Police Ticket          1       200        200      4.081633
# 10        Trip of Pebbles          1      3500       3500     71.428571
# 11                 Cement         25       285       7125    145.408163
# ...

# %%
df_fencing_clean = df_fencing.drop('total_dollar', axis=1)

# %%
df_fencing_clean
# Out:
#                       item quantity  unit_cost total_cost        date
# 0            Cutting Trees         1     10000      10000  04/30/2020
# 1         Big Trip of Sand         1      7500       7500  04/30/2020
# 2       Small Trip of Sand         1      4000       4000  04/30/2020
# 3                  Cement         40       285      11400  05/06/2020
# 4        Cement Transport          1       600        600  05/06/2020
# 5       Wheelbarrow Rental         1       200        200  05/06/2020
# 6           Molding Bricks      1370         5       6850  05/06/2020
# 7       Water for Molding          1      1000       1000  05/06/2020
# 8       Gas for Transport          1       450        450  05/06/2020
# 9           Police Ticket          1       200        200  04/29/2020
# 10        Trip of Pebbles          1      3500       3500  05/08/2020
# 11                 Cement         25       285       7125  05/08/2020
# ...

# %%
df_fencing_clean.to_csv('ParadiseView/out/df_fencing_clean.csv', index=False)

# %%
pd.read_csv('ParadiseView/out/df_fencing_clean.csv')
# Out:
#                       item  quantity   unit_cost  total_cost        date
# 0            Cutting Trees          1      10000       10000  04/30/2020
# 1         Big Trip of Sand          1       7500        7500  04/30/2020
# 2       Small Trip of Sand          1       4000        4000  04/30/2020
# 3                  Cement          40        285       11400  05/06/2020
# 4        Cement Transport           1        600         600  05/06/2020
# 5       Wheelbarrow Rental          1        200         200  05/06/2020
# 6           Molding Bricks       1370          5        6850  05/06/2020
# 7       Water for Molding           1       1000        1000  05/06/2020
# 8       Gas for Transport           1        450         450  05/06/2020
# 9           Police Ticket           1        200         200  04/29/2020
# 10        Trip of Pebbles           1       3500        3500  05/08/2020
# 11                 Cement          25        285        7125  05/08/2020
# ...

# %%
import pandas as pd
import numpy as np

# %%
otherExp = pd.read_excel("ParadiseView\Paradise View Expenditures 4.xlsx", skiprows=55, sheet_name="Fencing")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mrsuf\AppData\Local\Temp\ipykernel_13112\138199166.py:1: SyntaxWarning: invalid escape sequence '\P'
#   otherExp = pd.read_excel("ParadiseView\Paradise View Expenditures 4.xlsx", skiprows=55, sheet_name="Fencing")

# %%
otherExp
# Out:
#                      WHO  AMOUNT(D)   AMOUNT($)       DATE  Unnamed: 4  \
# 0              Papa jara     2000.0   40.816327 2020-03-23         NaN
# 1           Bubacarr Fai     1500.0   30.612245 2020-04-29         NaN
# 2              Papa jara     2000.0   40.816327 2020-05-23         NaN
# 3           Bubacarr Fai     2000.0   40.816327 2020-05-23         NaN
# 4             Papa Jara      2500.0   51.020408 2022-04-23         NaN
# 5           Bubacarr Fai     2500.0   51.020408 2022-04-23         NaN
# 6                    NaN        NaN         NaN        NaT         NaN
# 7                  Total    12500.0  255.102041        NaT         NaN
# 8                    NaN        NaN         NaN        NaT         NaN
# 9  1 Dollar = 49 Dalasis        NaN         NaN        NaT         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# ...

# %%
otherExp.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',], axis=1, inplace=True)

# %%
otherExp
# Out:
#                      WHO  AMOUNT(D)   AMOUNT($)       DATE
# 0              Papa jara     2000.0   40.816327 2020-03-23
# 1           Bubacarr Fai     1500.0   30.612245 2020-04-29
# 2              Papa jara     2000.0   40.816327 2020-05-23
# 3           Bubacarr Fai     2000.0   40.816327 2020-05-23
# 4             Papa Jara      2500.0   51.020408 2022-04-23
# 5           Bubacarr Fai     2500.0   51.020408 2022-04-23
# 6                    NaN        NaN         NaN        NaT
# 7                  Total    12500.0  255.102041        NaT
# 8                    NaN        NaN         NaN        NaT
# 9  1 Dollar = 49 Dalasis        NaN         NaN        NaT

# %%
otherExp.dropna(inplace=True)

# %%
otherExp
# Out:
#             WHO  AMOUNT(D)  AMOUNT($)       DATE
# 0     Papa jara     2000.0  40.816327 2020-03-23
# 1  Bubacarr Fai     1500.0  30.612245 2020-04-29
# 2     Papa jara     2000.0  40.816327 2020-05-23
# 3  Bubacarr Fai     2000.0  40.816327 2020-05-23
# 4    Papa Jara      2500.0  51.020408 2022-04-23
# 5  Bubacarr Fai     2500.0  51.020408 2022-04-23

# %%
otherExp.rename(columns={'WHO': 'item', 'AMOUNT(D)': 'unit_cost'}, inplace=True)

# %%
otherExp
# Out:
#            item  unit_cost  AMOUNT($)       DATE
# 0     Papa jara     2000.0  40.816327 2020-03-23
# 1  Bubacarr Fai     1500.0  30.612245 2020-04-29
# 2     Papa jara     2000.0  40.816327 2020-05-23
# 3  Bubacarr Fai     2000.0  40.816327 2020-05-23
# 4    Papa Jara      2500.0  51.020408 2022-04-23
# 5  Bubacarr Fai     2500.0  51.020408 2022-04-23

# %%
otherExp.columns
# Out:
# Index(['item', 'unit_cost', 'AMOUNT($)', 'DATE'], dtype='str')

# %%
otherExp.drop('AMOUNT($)', axis=1, inplace=True)

# %%
otherExp
# Out:
#            item  unit_cost       DATE
# 0     Papa jara     2000.0 2020-03-23
# 1  Bubacarr Fai     1500.0 2020-04-29
# 2     Papa jara     2000.0 2020-05-23
# 3  Bubacarr Fai     2000.0 2020-05-23
# 4    Papa Jara      2500.0 2022-04-23
# 5  Bubacarr Fai     2500.0 2022-04-23

# %%
otherExp.columns = otherExp.columns.str.lower()

# %%
otherExp
# Out:
#            item  unit_cost       date
# 0     Papa jara     2000.0 2020-03-23
# 1  Bubacarr Fai     1500.0 2020-04-29
# 2     Papa jara     2000.0 2020-05-23
# 3  Bubacarr Fai     2000.0 2020-05-23
# 4    Papa Jara      2500.0 2022-04-23
# 5  Bubacarr Fai     2500.0 2022-04-23

# %%
otherExp['date'] = otherExp['date'].dt.strftime('%m/%d/%Y')

# %%
otherExp
# Out:
#            item  unit_cost        date
# 0     Papa jara     2000.0  03/23/2020
# 1  Bubacarr Fai     1500.0  04/29/2020
# 2     Papa jara     2000.0  05/23/2020
# 3  Bubacarr Fai     2000.0  05/23/2020
# 4    Papa Jara      2500.0  04/23/2022
# 5  Bubacarr Fai     2500.0  04/23/2022

# %%
otherExp['quantity'] = 1

# %% [raw]
# otherExp

# %%
otherExp
# Out:
#            item  unit_cost        date  quantity
# 0     Papa jara     2000.0  03/23/2020         1
# 1  Bubacarr Fai     1500.0  04/29/2020         1
# 2     Papa jara     2000.0  05/23/2020         1
# 3  Bubacarr Fai     2000.0  05/23/2020         1
# 4    Papa Jara      2500.0  04/23/2022         1
# 5  Bubacarr Fai     2500.0  04/23/2022         1

# %%
otherExp['total_cost'] = otherExp['unit_cost'] * otherExp['quantity']

# %%
otherExp
# Out:
#            item  unit_cost        date  quantity  total_cost
# 0     Papa jara     2000.0  03/23/2020         1      2000.0
# 1  Bubacarr Fai     1500.0  04/29/2020         1      1500.0
# 2     Papa jara     2000.0  05/23/2020         1      2000.0
# 3  Bubacarr Fai     2000.0  05/23/2020         1      2000.0
# 4    Papa Jara      2500.0  04/23/2022         1      2500.0
# 5  Bubacarr Fai     2500.0  04/23/2022         1      2500.0

# %%
otherExp = otherExp.reindex(columns=['item', 'quantity', 'unit_cost', 'total_cost', 'date'])

# %%
otherExp
# Out:
#            item  quantity  unit_cost  total_cost        date
# 0     Papa jara         1     2000.0      2000.0  03/23/2020
# 1  Bubacarr Fai         1     1500.0      1500.0  04/29/2020
# 2     Papa jara         1     2000.0      2000.0  05/23/2020
# 3  Bubacarr Fai         1     2000.0      2000.0  05/23/2020
# 4    Papa Jara          1     2500.0      2500.0  04/23/2022
# 5  Bubacarr Fai         1     2500.0      2500.0  04/23/2022

# %%
otherExp.to_csv('ParadiseView/out/df_otherExp_clean.csv', index=False)

# %%
otherExp = pd.read_csv('ParadiseView/out/df_otherExp_clean.csv')

# %%
otherExp
# Out:
#            item  quantity  unit_cost  total_cost        date
# 0     Papa jara         1     2000.0      2000.0  03/23/2020
# 1  Bubacarr Fai         1     1500.0      1500.0  04/29/2020
# 2     Papa jara         1     2000.0      2000.0  05/23/2020
# 3  Bubacarr Fai         1     2000.0      2000.0  05/23/2020
# 4    Papa Jara          1     2500.0      2500.0  04/23/2022
# 5  Bubacarr Fai         1     2500.0      2500.0  04/23/2022

# %%
otherExp['item'] = np.where(otherExp['item'].str.contains('Papa jara', case=False, na=False), 'Papa Jara', otherExp['item'])

# %%
otherExp['item'] = np.where(otherExp['item'].str.contains('Bubacarr Fai', case=False, na=False), 'Bubacarr Faye', otherExp['item'])

# %%
otherExp
# Out:
#             item  quantity  unit_cost  total_cost        date
# 0      Papa Jara         1     2000.0      2000.0  03/23/2020
# 1  Bubacarr Faye         1     1500.0      1500.0  04/29/2020
# 2      Papa Jara         1     2000.0      2000.0  05/23/2020
# 3  Bubacarr Faye         1     2000.0      2000.0  05/23/2020
# 4      Papa Jara         1     2500.0      2500.0  04/23/2022
# 5  Bubacarr Faye         1     2500.0      2500.0  04/23/2022

# %%
otherExp['sub_category'] = 'Fencing'
otherExp['category'] = 'Preconstruction'
otherExp['exchange_rate'] = 49.00

# %%
otherExp['date'] = np.where(otherExp['date'] == pd.to_datetime('2022-04-23'), pd.to_datetime('2020-04-23'), otherExp['date'])

# %%
otherExp['date'] = pd.to_datetime(otherExp['date'])

# %%
otherExp
# Out:
#             item  quantity  unit_cost  total_cost       date sub_category  \
# 0      Papa Jara         1     2000.0      2000.0 2020-03-23      Fencing
# 1  Bubacarr Faye         1     1500.0      1500.0 2020-04-29      Fencing
# 2      Papa Jara         1     2000.0      2000.0 2020-05-23      Fencing
# 3  Bubacarr Faye         1     2000.0      2000.0 2020-05-23      Fencing
# 4      Papa Jara         1     2500.0      2500.0 2020-04-23      Fencing
# 5  Bubacarr Faye         1     2500.0      2500.0 2020-04-23      Fencing
#
#           category  exchange_rate
# 0  Preconstruction           49.0
# 1  Preconstruction           49.0
# 2  Preconstruction           49.0
# 3  Preconstruction           49.0
# 4  Preconstruction           49.0
# 5  Preconstruction           49.0

# %%
otherExp.to_csv('ParadiseView/out/df_otherExp_clean.csv', index=False)

# %%
filepath = "ParadiseView/Paradise View Expenditures 4.xlsx"
outFilePath = 'ParadiseView/out',

# %%
f_floorMolding = pd.read_excel(filepath, sheet_name='Brick Molding', skiprows=4)

# %%
f_floorMolding
# Out:
#                       ITEM  QUANTITY             UNIT PRICE(D)  TOTAL COST(D)  \
# 0        $100 Transfer Fee          1                      250            250
# 1            Cutting Trees          1                     5000           5000
# 2            Clearing Plot          1                     2500           2500
# 3                      NaN        NaN                      NaN            NaN
# 4                    Total        NaN                     7750           7750
# 5                      NaN        NaN                      NaN            NaN
# 6    1 Dollar = 50 Dalasis        NaN                      NaN            NaN
# 7                      NaN        NaN                      NaN            NaN
# 8                      NaN        NaN                      NaN            NaN
# 9                      NaN        NaN                      NaN            NaN
# 10                     NaN        NaN  BRICK MOLDING EXPENSES             NaN
# ...

# %%
f_floorMolding.drop(columns=['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], inplace=True)

# %%
f_floorMolding
# Out:
#                       ITEM  QUANTITY             UNIT PRICE(D)  TOTAL COST(D)  \
# 0        $100 Transfer Fee          1                      250            250
# 1            Cutting Trees          1                     5000           5000
# 2            Clearing Plot          1                     2500           2500
# 3                      NaN        NaN                      NaN            NaN
# 4                    Total        NaN                     7750           7750
# 5                      NaN        NaN                      NaN            NaN
# 6    1 Dollar = 50 Dalasis        NaN                      NaN            NaN
# 7                      NaN        NaN                      NaN            NaN
# 8                      NaN        NaN                      NaN            NaN
# 9                      NaN        NaN                      NaN            NaN
# 10                     NaN        NaN  BRICK MOLDING EXPENSES             NaN
# ...

# %%
f_floorMolding.dropna(thresh=len(f_floorMolding.columns) - 1, inplace=True)

# %%
f_floorMolding
# Out:
#                       ITEM  QUANTITY   UNIT PRICE(D)  TOTAL COST(D)  COST($)  \
# 0        $100 Transfer Fee          1            250            250        5
# 1            Cutting Trees          1           5000           5000      100
# 2            Clearing Plot          1           2500           2500       50
# 11                    ITEM  QUANTITY   UNIT PRICE(D)  TOTAL COST(D)  COST($)
# 12     $1,000 Transfer Fee          1           1000           1000       20
# 13                 Cement          75            320          24000      480
# 14        Cement Transport         75             20           1500       30
# 15            Wheelbarrow           1           3000           3000       60
# 16          50m Hose/Pipe           1           1400           1400       28
# 17           Small Bucket           2            100            200        4
# 18           Big Sand Trip          2           8000          16000      320
# ...

# %%
f_floorMolding
# Out:
#                       ITEM  QUANTITY   UNIT PRICE(D)  TOTAL COST(D)  COST($)  \
# 0        $100 Transfer Fee          1            250            250        5
# 1            Cutting Trees          1           5000           5000      100
# 2            Clearing Plot          1           2500           2500       50
# 11                    ITEM  QUANTITY   UNIT PRICE(D)  TOTAL COST(D)  COST($)
# 12     $1,000 Transfer Fee          1           1000           1000       20
# 13                 Cement          75            320          24000      480
# 14        Cement Transport         75             20           1500       30
# 15            Wheelbarrow           1           3000           3000       60
# 16          50m Hose/Pipe           1           1400           1400       28
# 17           Small Bucket           2            100            200        4
# 18           Big Sand Trip          2           8000          16000      320
# ...

# %%
f_floorMolding.drop(f_floorMolding[f_floorMolding['ITEM'] == 'ITEM'].index, inplace =True)

# %%
f_floorMolding
# Out:
#                       ITEM QUANTITY  UNIT PRICE(D) TOTAL COST(D) COST($)  \
# 0        $100 Transfer Fee         1           250           250       5
# 1            Cutting Trees         1          5000          5000     100
# 2            Clearing Plot         1          2500          2500      50
# 12     $1,000 Transfer Fee         1          1000          1000      20
# 13                 Cement         75           320         24000     480
# 14        Cement Transport        75            20          1500      30
# 15            Wheelbarrow          1          3000          3000      60
# 16          50m Hose/Pipe          1          1400          1400      28
# 17           Small Bucket          2           100           200       4
# 18           Big Sand Trip         2          8000         16000     320
# 19             Small Tank          1          1600          1600      32
# 20         Cement Watchman         1           500           500      10
# ...

# %%
f_floorMolding.columns = f_floorMolding.columns.str.lower()

# %%
f_floorMolding.head()
# Out:
#                    item quantity  unit price(d) total cost(d) cost($)  \
# 0     $100 Transfer Fee         1           250           250       5
# 1         Cutting Trees         1          5000          5000     100
# 2         Clearing Plot         1          2500          2500      50
# 12  $1,000 Transfer Fee         1          1000          1000      20
# 13              Cement         75           320         24000     480
#
#                    date
# 0   2022-03-27 00:00:00
# 1   2022-04-03 00:00:00
# 2   2022-04-03 00:00:00
# 12  2022-04-16 00:00:00
# 13  2022-04-18 00:00:00

# %%
f_floorMolding.rename(columns={'unit price(d)': 'unit_cost', 'total cost(d)': 'total_cost'}, inplace=True)

# %%
f_floorMolding.head()
# Out:
#                    item quantity  unit_cost total_cost cost($)  \
# 0     $100 Transfer Fee         1       250        250       5
# 1         Cutting Trees         1      5000       5000     100
# 2         Clearing Plot         1      2500       2500      50
# 12  $1,000 Transfer Fee         1      1000       1000      20
# 13              Cement         75       320      24000     480
#
#                    date
# 0   2022-03-27 00:00:00
# 1   2022-04-03 00:00:00
# 2   2022-04-03 00:00:00
# 12  2022-04-16 00:00:00
# 13  2022-04-18 00:00:00

# %%
f_floorMolding.drop(columns='cost($)', inplace=True)

# %%
#f_floorMolding['date'] = f_floorMolding['date'].dt.strftime('%m/%d/%Y')

# %%
f_floorMolding
# Out:
#                       item quantity  unit_cost total_cost                 date
# 0        $100 Transfer Fee         1       250        250  2022-03-27 00:00:00
# 1            Cutting Trees         1      5000       5000  2022-04-03 00:00:00
# 2            Clearing Plot         1      2500       2500  2022-04-03 00:00:00
# 12     $1,000 Transfer Fee         1      1000       1000  2022-04-16 00:00:00
# 13                 Cement         75       320      24000  2022-04-18 00:00:00
# 14        Cement Transport        75        20       1500  2022-04-18 00:00:00
# 15            Wheelbarrow          1      3000       3000  2022-04-18 00:00:00
# 16          50m Hose/Pipe          1      1400       1400  2022-04-18 00:00:00
# 17           Small Bucket          2       100        200  2022-04-18 00:00:00
# 18           Big Sand Trip         2      8000      16000  2022-04-18 00:00:00
# 19             Small Tank          1      1600       1600  2022-04-18 00:00:00
# ...

# %%
import pandas as pd
from datetime import date, datetime

# %%
f_floorMolding.at[22, 'date'] = '2022-04-18 00:00:00'

# %%
f_floorMolding.loc[32:, 'date'] = '2022-04-23 00:00:00'

# %%
f_floorMolding.loc[f_floorMolding['item'] == 'Missing', 'date'] = 1

# %%
f_floorMolding.at[32, 'unit_cost'] = 6.00

# %%
f_floorMolding.at[22, 'unit_cost'] = 1500

# %%
f_floorMolding.at[39, 'quantity '] = 1
f_floorMolding.at[39, 'unit_cost'] = 15

# %%
f_floorMolding.columns
# Out:
# Index(['item', 'quantity', 'unit_cost', 'total_cost', 'date'], dtype='str')

# %%
f_floorMolding['date'] = pd.to_datetime(f_floorMolding['date'])

# %%
f_floorMolding['date'].info
# Out:
# <bound method Series.info of 0    2022-03-27
# 1    2022-04-03
# 2    2022-04-03
# 12   2022-04-16
# 13   2022-04-18
# 14   2022-04-18
# 15   2022-04-18
# 16   2022-04-18
# 17   2022-04-18
# 18   2022-04-18
# 19   2022-04-18
# 20   2022-04-18
# 21   2022-04-18
# 22   2022-04-18
# 23   2022-04-19
# 24   2022-04-20
# 25   2022-04-20
# 26   2022-04-20
# 27   2022-04-20
# 28   2022-04-20
# 29   2022-04-20
# 30   2022-04-22
# 31   2022-04-23
# 32   2022-04-23
# 33   2022-04-23
# 34   2022-04-23
# 35   2022-04-23
# 36   2022-04-23
# 37   2022-04-23
# 38   2022-04-23
# 39   2022-04-23
# Name: date, dtype: datetime64[us]>

# %%
f_floorMolding['date'] = f_floorMolding['date'].dt.strftime('%m/%d/%Y')

# %%
f_floorMolding
# Out:
#                       item quantity unit_cost total_cost        date
# 0        $100 Transfer Fee        1       250        250  03/27/2022
# 1            Cutting Trees        1      5000       5000  04/03/2022
# 2            Clearing Plot        1      2500       2500  04/03/2022
# 12     $1,000 Transfer Fee        1      1000       1000  04/16/2022
# 13                 Cement        75       320      24000  04/18/2022
# 14        Cement Transport       75        20       1500  04/18/2022
# 15            Wheelbarrow         1      3000       3000  04/18/2022
# 16          50m Hose/Pipe         1      1400       1400  04/18/2022
# 17           Small Bucket         2       100        200  04/18/2022
# 18           Big Sand Trip        2      8000      16000  04/18/2022
# 19             Small Tank         1      1600       1600  04/18/2022
# 20         Cement Watchman        1       500        500  04/18/2022
# 21               Gasoline         1       300        300  04/18/2022
# ...

# %%
f_floorMolding['sub_category'] = 'Brick Molding'

# %%
f_floorMolding['category'] = '1st Floor'

# %%
f_floorMolding
# Out:
#                       item quantity unit_cost total_cost        date  \
# 0        $100 Transfer Fee        1       250        250  03/27/2022
# 1            Cutting Trees        1      5000       5000  04/03/2022
# 2            Clearing Plot        1      2500       2500  04/03/2022
# 12     $1,000 Transfer Fee        1      1000       1000  04/16/2022
# 13                 Cement        75       320      24000  04/18/2022
# 14        Cement Transport       75        20       1500  04/18/2022
# 15            Wheelbarrow         1      3000       3000  04/18/2022
# 16          50m Hose/Pipe         1      1400       1400  04/18/2022
# 17           Small Bucket         2       100        200  04/18/2022
# 18           Big Sand Trip        2      8000      16000  04/18/2022
# 19             Small Tank         1      1600       1600  04/18/2022
# 20         Cement Watchman        1       500        500  04/18/2022
# 21               Gasoline         1       300        300  04/18/2022
# ...

# %%
f_floorMolding.to_csv('ParadiseView/out/df_ffBrickMoldingClean.csv', index=False)  # 'ParadiseView/out/df_otherExp_clean.csv'

# %%
pd.read_csv('ParadiseView/out/df_ffBrickMoldingClean.csv')
# Out:
#                       item  quantity  unit_cost  total_cost        date  \
# 0        $100 Transfer Fee         1      250.0         250  03/27/2022
# 1            Cutting Trees         1     5000.0        5000  04/03/2022
# 2            Clearing Plot         1     2500.0        2500  04/03/2022
# 3      $1,000 Transfer Fee         1     1000.0        1000  04/16/2022
# 4                  Cement         75      320.0       24000  04/18/2022
# 5         Cement Transport        75       20.0        1500  04/18/2022
# 6             Wheelbarrow          1     3000.0        3000  04/18/2022
# 7           50m Hose/Pipe          1     1400.0        1400  04/18/2022
# 8            Small Bucket          2      100.0         200  04/18/2022
# 9            Big Sand Trip         2     8000.0       16000  04/18/2022
# 10             Small Tank          1     1600.0        1600  04/18/2022
# 11         Cement Watchman         1      500.0         500  04/18/2022
# ...
