# %%
import numpy as np
import pandas as pd

# %%
secondfloor_roof = pd.read_csv('ParadiseView/Paradise View/2nd Floor Construction Roof Concreting.csv',)

# %%
secondfloor_roof
# Out:
#                           ITEM  QUALITY  UNIT PRICE(D) TOTAL COST(D)  \
# 0                     1/2 wood     100.0           100        10,000
# 1          1/2 Wood Transport        1.0         1,000         1,000
# 2       Concrete Nail 2 1/2 in       5.0           200         1,000
# 3           Concrete Nail 2 in      45.0            30         1,350
# 4                     1/2 Wood      35.0           100         3,500
# ..                         ...       ...           ...           ...
# 114                        NaN       NaN           NaN           NaN
# 115                        NaN       NaN           NaN           NaN
# 116         TOTAL AMOUNT SPENT       NaN           NaN  1,017,906.00
# 117                        NaN       NaN           NaN           NaN
# 118  REMAINING BALANCE IN HAND       NaN           NaN          0.00
#
#            DATE Unnamed: 5
# 0    12/05/2025        NaN
# 1    12/05/2025        NaN
# 2    12/05/2025        NaN
# ...

# %%
secondfloor_roof.drop(columns='Unnamed: 5', inplace=True)

# %%
secondfloor_roof.drop(secondfloor_roof.loc[86:].index)
# Out:
#                                  item  quantity unit_cost total_cost  \
# 0                            1/2 wood     100.0       100     10,000
# 1                 1/2 Wood Transport        1.0     1,000      1,000
# 2              Concrete Nail 2 1/2 in       5.0       200      1,000
# 3                  Concrete Nail 2 in      45.0        30      1,350
# 4                            1/2 Wood      35.0       100      3,500
# ..                                ...       ...       ...        ...
# 81   2/3 Wood Rental 2Days Extension      375.0         5      5,625
# 82   Acrojack Rental 2Days Extension      475.0       2.5      3,565
# 83            Carpenter Sana Payment        1.0     1,500      1,500
# 84             Bubacarr Faye Payment        1.0    12,000     12,000
# 85  Ali moving the Woods  to the Room       1.0       481        481
#
#           date
# 0   12/05/2025
# 1   12/05/2025
# 2   12/05/2025
# 3   12/05/2025
# 4   12/06/2025
# ..         ...
# 81  01/18/2026
# ...

# %%
secondfloor_roof.columns = secondfloor_roof.columns.str.lower()

# %%
secondfloor_roof.columns
# Out:
# Index(['item', 'quality ', 'unit price(d)', 'total cost(d)', 'date'], dtype='str')

# %%
secondfloor_roof.rename(columns={'quality ': 'quantity', 'unit price(d)': 'unit_cost', 'total cost(d)': 'total_cost'}, inplace=True)

# %%
secondfloor_roof.columns
# Out:
# Index(['item', 'quantity', 'unit_cost', 'total_cost', 'date'], dtype='str')

# %%
secondfloor_roof[secondfloor_roof['item'] == 'Sand']
# Out:
#     item  quantity unit_cost total_cost        date
# 42  Sand       3.0     8,000     24,000  12/26/2025

# %%
secondfloor_roof.loc[42, ['quantity', 'total_cost']] = [2.0, '16000']

# %%
#secondfloor_roof.drop(columns=['qauntity', 'qantity'], inplace=True)

# %%
#secondfloor_roof.columns = secondfloor_roof.columns.str.lower

# %%
secondfloor_roof.columns
# Out:
# Index(['item', 'quantity', 'unit_cost', 'total_cost', 'date'], dtype='str')

# %%
secondfloor_roof.drop(secondfloor_roof.loc[86:].index, inplace =True)

# %%
print(secondfloor_roof.to_string())
# Out:
#                                      item  quantity unit_cost total_cost        date
# 0                                1/2 wood     100.0       100     10,000  12/05/2025
# 1                     1/2 Wood Transport        1.0     1,000      1,000  12/05/2025
# 2                  Concrete Nail 2 1/2 in       5.0       200      1,000  12/05/2025
# 3                      Concrete Nail 2 in      45.0        30      1,350  12/05/2025
# 4                                1/2 Wood      35.0       100      3,500  12/06/2025
# 5                                1/6 Wood       2.0       350        700  12/06/2025
# 6                         Wood Transport        1.0       500        500  12/06/2025
# 7                 Carpenter Sana Payment        1.0    15,000     15,000  12/06/2025
# 8                                2/3 Wood     350.0         5     52,500  12/13/2025
# 9                                Nail(pkg      17.0       100      1,700  12/13/2025
# ...

# %%
secondfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        86 non-null     str
#  1   quantity    86 non-null     float64
#  2   unit_cost   86 non-null     str
#  3   total_cost  86 non-null     str
#  4   date        84 non-null     str
# dtypes: float64(1), str(4)
# memory usage: 3.5 KB

# %%
secondfloor_roof.loc[secondfloor_roof['date'].isna()]
# Out:
# Empty DataFrame
# Columns: [item, quantity, unit_cost, total_cost, date]
# Index: []

# %%
secondfloor_roof.loc[[74, 75], 'date'] = '12/31/2026'

# %%
secondfloor_roof.loc[[74, 75]]
# Out:
#                   item  quantity unit_cost total_cost        date
# 74  Gas for Generator        1.0       500        500  12/31/2026
# 75  Gas for Generator        1.0       500        500  12/31/2026

# %%
print(secondfloor_roof.to_string())
# Out:
#                                      item  quantity unit_cost total_cost        date
# 0                                1/2 wood     100.0       100     10,000  12/05/2025
# 1                     1/2 Wood Transport        1.0     1,000      1,000  12/05/2025
# 2                  Concrete Nail 2 1/2 in       5.0       200      1,000  12/05/2025
# 3                      Concrete Nail 2 in      45.0        30      1,350  12/05/2025
# 4                                1/2 Wood      35.0       100      3,500  12/06/2025
# 5                                1/6 Wood       2.0       350        700  12/06/2025
# 6                         Wood Transport        1.0       500        500  12/06/2025
# 7                 Carpenter Sana Payment        1.0    15,000     15,000  12/06/2025
# 8                                2/3 Wood     350.0         5     52,500  12/13/2025
# 9                                Nail(pkg      17.0       100      1,700  12/13/2025
# ...

# %%
secondfloor_roof.loc[18, 'date'] = '12/22/2025'

# %%
secondfloor_roof['date'] = pd.to_datetime(secondfloor_roof['date'])

# %%
secondfloor_roof['date'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 86 entries, 0 to 85
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 86 non-null     datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 820.0 bytes

# %%
secondfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        86 non-null     str
#  1   quantity    86 non-null     float64
#  2   unit_cost   86 non-null     str
#  3   total_cost  86 non-null     str
#  4   date        86 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 3.5 KB

# %%
secondfloor_roof.to_csv('ParadiseView/out/df_secondfloor_roof.csv', index=False)

# %%
secondfloor_roof = pd.read_csv('ParadiseView/out/df_secondfloor_roof.csv')

# %%
secondfloor_roof
# Out:
#                                  item  quantity unit_cost total_cost  \
# 0                            1/2 wood     100.0       100     10,000
# 1                 1/2 Wood Transport        1.0     1,000      1,000
# 2              Concrete Nail 2 1/2 in       5.0       200      1,000
# 3                  Concrete Nail 2 in      45.0        30      1,350
# 4                            1/2 Wood      35.0       100      3,500
# ..                                ...       ...       ...        ...
# 81   2/3 Wood Rental 2Days Extension      375.0         5      5,625
# 82   Acrojack Rental 2Days Extension      475.0       2.5      3,565
# 83            Carpenter Sana Payment        1.0     1,500      1,500
# 84             Bubacarr Faye Payment        1.0    12,000     12,000
# 85  Ali moving the Woods  to the Room       1.0       481        481
#
#           date
# 0   2025-12-05
# 1   2025-12-05
# 2   2025-12-05
# 3   2025-12-05
# 4   2025-12-06
# ..         ...
# 81  2026-01-18
# ...

# %%
secondfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        86 non-null     str
#  1   quantity    86 non-null     float64
#  2   unit_cost   86 non-null     str
#  3   total_cost  86 non-null     str
#  4   date        86 non-null     str
# dtypes: float64(1), str(4)
# memory usage: 3.5 KB

# %%
secondfloor_roof['unit_cost'] = secondfloor_roof['unit_cost'].str.replace(",", "").astype('float64')

# %%
secondfloor_roof['total_cost'] = secondfloor_roof['total_cost'].str.replace(',', '').astype('float64')

# %%
secondfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        86 non-null     str
#  1   quantity    86 non-null     float64
#  2   unit_cost   86 non-null     float64
#  3   total_cost  86 non-null     float64
#  4   date        86 non-null     str
# dtypes: float64(3), str(2)
# memory usage: 3.5 KB

# %%
secondfloor_roof['date'] = pd.to_datetime(secondfloor_roof['date'])

# %%
secondfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        86 non-null     str
#  1   quantity    86 non-null     float64
#  2   unit_cost   86 non-null     float64
#  3   total_cost  86 non-null     float64
#  4   date        86 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(3), str(1)
# memory usage: 3.5 KB

# %%
secondfloor_roof['sub_category'] = 'Roof Concreting'
secondfloor_roof['category'] = '2nd Floor'

# %%
secondfloor_roof.to_csv('ParadiseView/out/df_secondfloor_roof.csv', index=False)

# %%
secondfloor_roof = pd.read_csv('ParadiseView/out/df_secondfloor_roof.csv')

# %%
print(secondfloor_roof.to_string())
# Out:
#                                      item  quantity  unit_cost  total_cost        date     sub_category   category
# 0                                1/2 wood     100.0      100.0     10000.0  2025-12-05  Roof Conrecting  2nd Floor
# 1                     1/2 Wood Transport        1.0     1000.0      1000.0  2025-12-05  Roof Conrecting  2nd Floor
# 2                  Concrete Nail 2 1/2 in       5.0      200.0      1000.0  2025-12-05  Roof Conrecting  2nd Floor
# 3                      Concrete Nail 2 in      45.0       30.0      1350.0  2025-12-05  Roof Conrecting  2nd Floor
# 4                                1/2 Wood      35.0      100.0      3500.0  2025-12-06  Roof Conrecting  2nd Floor
# 5                                1/6 Wood       2.0      350.0       700.0  2025-12-06  Roof Conrecting  2nd Floor
# 6                         Wood Transport        1.0      500.0       500.0  2025-12-06  Roof Conrecting  2nd Floor
# ...

# %%
secondfloor_roof['date'][secondfloor_roof['date'].between('2025-12-05', '2025-12-25')]
# Out:
# 0     2025-12-05
# 1     2025-12-05
# 2     2025-12-05
# 3     2025-12-05
# 4     2025-12-06
# 5     2025-12-06
# 6     2025-12-06
# 7     2025-12-06
# 8     2025-12-13
# 9     2025-12-13
# 10    2025-12-13
# 11    2025-12-23
# 12    2025-12-15
# 13    2025-12-17
# 14    2025-12-17
# 15    2025-12-17
# 16    2025-12-18
# 17    2025-12-20
# 18    2025-12-22
# 19    2025-12-22
# 20    2025-12-22
# 21    2025-12-23
# 22    2025-12-23
# 23    2025-12-23
# 24    2025-12-23
# 25    2025-12-23
# 26    2025-12-23
# 27    2025-12-23
# 28    2025-12-23
# 29    2025-12-24
# 30    2025-12-24
# 31    2025-12-24
# 32    2025-12-24
# Name: date, dtype: str

# %%
secondfloor_roof['exchange_rate'] = np.where(secondfloor_roof['date'].between('2025-12-05', '2025-12-25'), 74.25, 0)

# %%
secondfloor_roof
# Out:
#                                  item  quantity  unit_cost  total_cost  \
# 0                            1/2 wood     100.0      100.0     10000.0
# 1                 1/2 Wood Transport        1.0     1000.0      1000.0
# 2              Concrete Nail 2 1/2 in       5.0      200.0      1000.0
# 3                  Concrete Nail 2 in      45.0       30.0      1350.0
# 4                            1/2 Wood      35.0      100.0      3500.0
# ..                                ...       ...        ...         ...
# 81   2/3 Wood Rental 2Days Extension      375.0        5.0      5625.0
# 82   Acrojack Rental 2Days Extension      475.0        2.5      3565.0
# 83            Carpenter Sana Payment        1.0     1500.0      1500.0
# 84             Bubacarr Faye Payment        1.0    12000.0     12000.0
# 85  Ali moving the Woods  to the Room       1.0      481.0       481.0
#
#          date     sub_category   category  exchange_rate
# 0  2025-12-05  Roof Conrecting  2nd Floor          74.25
# ...

# %%
secondfloor_roof.loc[secondfloor_roof['date'].between('2025-12-26', '2025-12-28'), 'exchange_rate'] = 74.10

# %%
secondfloor_roof.loc[secondfloor_roof['date'].between('2025-12-29', '2026-01-22'), 'exchange_rate'] = 74

# %%
secondfloor_roof
# Out:
#                                  item  quantity  unit_cost  total_cost  \
# 0                            1/2 wood     100.0      100.0     10000.0
# 1                 1/2 Wood Transport        1.0     1000.0      1000.0
# 2              Concrete Nail 2 1/2 in       5.0      200.0      1000.0
# 3                  Concrete Nail 2 in      45.0       30.0      1350.0
# 4                            1/2 Wood      35.0      100.0      3500.0
# ..                                ...       ...        ...         ...
# 81   2/3 Wood Rental 2Days Extension      375.0        5.0      5625.0
# 82   Acrojack Rental 2Days Extension      475.0        2.5      3565.0
# 83            Carpenter Sana Payment        1.0     1500.0      1500.0
# 84             Bubacarr Faye Payment        1.0    12000.0     12000.0
# 85  Ali moving the Woods  to the Room       1.0      481.0       481.0
#
#           date     sub_category   category  exchange_rate
# ...

# %%
print(secondfloor_roof.to_string())
# Out:
#                                      item  quantity  unit_cost  total_cost       date     sub_category   category  exchange_rate
# 0                                1/2 wood     100.0      100.0     10000.0 2025-12-05  Roof Conrecting  2nd Floor          74.25
# 1                     1/2 Wood Transport        1.0     1000.0      1000.0 2025-12-05  Roof Conrecting  2nd Floor          74.25
# 2                  Concrete Nail 2 1/2 in       5.0      200.0      1000.0 2025-12-05  Roof Conrecting  2nd Floor          74.25
# 3                      Concrete Nail 2 in      45.0       30.0      1350.0 2025-12-05  Roof Conrecting  2nd Floor          74.25
# 4                                1/2 Wood      35.0      100.0      3500.0 2025-12-06  Roof Conrecting  2nd Floor          74.25
# 5                                1/6 Wood       2.0      350.0       700.0 2025-12-06  Roof Conrecting  2nd Floor          74.25
# ...

# %%
# secondfloor_roof['date'] = np.select([secondfloor_roof['date'] == '2026-01-31',  
#                                       secondfloor_roof['date'] == '2026-12-31'], ['2025-12-31', '2025-12-31'], 
#                                                    default =secondfloor_roof['date'])

# %%
secondfloor_roof['date'] = pd.to_datetime(secondfloor_roof['date'])

# %%
secondfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           86 non-null     str
#  1   quantity       86 non-null     float64
#  2   unit_cost      86 non-null     float64
#  3   total_cost     86 non-null     float64
#  4   date           86 non-null     datetime64[us]
#  5   sub_category   86 non-null     str
#  6   category       86 non-null     str
#  7   exchange_rate  86 non-null     float64
# dtypes: datetime64[us](1), float64(4), str(3)
# memory usage: 5.5 KB

# %%
#secondfloor_roof['item'] = 
secondfloor_roof['item'] = np.where(secondfloor_roof['item'] == '2/3 Wood', '2/3 Wood Rental', secondfloor_roof['item'])

# %%
secondfloor_roof.at[53, 'item'] = 'Electrical Materials'

# %%
secondfloor_roof.at[9, 'item'] = 'Nail(pkg)'

# %%
df = secondfloor_roof[secondfloor_roof['item'] == 'Acrojack ']

# %%
df
# Out:
#                item  quantity  unit_cost  total_cost       date  \
# 12  Arcojack Rental     400.0        2.5     27000.0 2025-12-15
# 19  Arcojack Rental      50.0        2.5       400.0 2025-12-22
# 46  Arcojack Rental      25.0        2.5      1000.0 2025-12-27
#
#        sub_category   category  exchange_rate
# 12  Roof Conrecting  2nd Floor          74.25
# 19  Roof Conrecting  2nd Floor          74.25
# 46  Roof Conrecting  2nd Floor          74.10

# %%
secondfloor_roof['item'] = np.where(secondfloor_roof['item'] == 'Acrojack ', 'Arcojack Rental', secondfloor_roof['item'])

# %%
secondfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           86 non-null     str
#  1   quantity       86 non-null     float64
#  2   unit_cost      86 non-null     float64
#  3   total_cost     86 non-null     float64
#  4   date           86 non-null     datetime64[us]
#  5   sub_category   86 non-null     str
#  6   category       86 non-null     str
#  7   exchange_rate  86 non-null     float64
# dtypes: datetime64[us](1), float64(4), str(3)
# memory usage: 5.5 KB

# %%
print(secondfloor_roof.to_string())
# Out:
#                                      item  quantity  unit_cost  total_cost        date     sub_category   category  exchange_rate
# 0                                1/2 wood     100.0      100.0     10000.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 1                     1/2 Wood Transport        1.0     1000.0      1000.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 2                  Concrete Nail 2 1/2 in       5.0      200.0      1000.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 3                      Concrete Nail 2 in      45.0       30.0      1350.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 4                                1/2 Wood      35.0      100.0      3500.0  2025-12-06  Roof Concreting  2nd Floor          74.25
# 5                                1/6 Wood       2.0      350.0       700.0  2025-12-06  Roof Concreting  2nd Floor          74.25
# ...

# %%
secondfloor_roof.to_csv('ParadiseView/out/df_secondfloor_roof.csv', index=False)

# %%
pd.read_csv('ParadiseView/out/df_secondfloor_roof.csv')
