# %%
import pandas as pd
import numpy as np
from datetime import date, datetime

# %%
firstFloor_const = pd.read_excel('ParadiseView/Paradise View Expenditures 4.xlsx', sheet_name='1st Floor Construction ', skiprows=5)

# %%
firstFloor_const
# Out:
#                             ITEM QUANTITY   UNIT PRICE(D)  TOTAL COST(D)  \
# 0                    1 by 2 wood        25          100.0         2500.0
# 1                    Wooden Pake        15           35.0          500.0
# 2             3 Inches Nale(kg)          2          100.0          200.0
# 3    2 and half Inches Nale(kg)          2          100.0          200.0
# 4      Materials Transportation          1          500.0          500.0
# ..                           ...       ...            ...            ...
# 408                          NaN       NaN            NaN            NaN
# 409                          NaN       NaN            NaN            NaN
# 410                          NaN       NaN            NaN            NaN
# 411                          NaN                      NaN            NaN
# 412                          NaN       NaN            NaN            NaN
#
#      TOTAL COST($)                 Date Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
firstFloor_const.drop(columns=['Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15'], inplace=True)

# %%
firstFloor_const.drop(firstFloor_const[360:].index, inplace=True)

# %%
firstFloor_const.tail(20)
# Out:
#                                    ITEM QUANTITY   UNIT PRICE(D)  \
# 340                             Cement         25            NaN
# 341                Momo Waggeh Watering         1         2100.0
# 342      Momo Waggeh Salary(Upto May 7)         1         1000.0
# 343  Returning Roof Concrete Materials          1         8500.0
# 344                                 NaN       NaN            NaN
# 345                                 NaN       NaN            NaN
# 346                                 NaN       NaN       369010.0
# 347                                 NaN       NaN            NaN
# 348                                 NaN       NaN            NaN
# 349                                 NaN       NaN            NaN
# 350                                 NaN       NaN       965810.0
# 351                                 NaN       NaN            NaN
# 352                                 NaN       NaN            NaN
# ...

# %%
firstFloor_const.drop(firstFloor_const.tail(16).index, inplace=True)

# %%
firstFloor_const.dropna(thresh=2, inplace=True)

# %%
firstFloor_const.tail()
# Out:
#                                    ITEM QUANTITY   UNIT PRICE(D)  \
# 339                    Stone(10 Wheels)         1        14000.0
# 340                             Cement         25            NaN
# 341                Momo Waggeh Watering         1         2100.0
# 342      Momo Waggeh Salary(Upto May 7)         1         1000.0
# 343  Returning Roof Concrete Materials          1         8500.0
#
#      TOTAL COST(D)  TOTAL COST($)                 Date
# 339        14000.0            NaN  2025-04-24 00:00:00
# 340            NaN            NaN  2025-04-24 00:00:00
# 341         2100.0            NaN  2025-05-10 00:00:00
# 342         1000.0            NaN  2025-05-10 00:00:00
# 343         8500.0            NaN  2025-05-17 00:00:00

# %%
firstFloor_const.columns= firstFloor_const.columns.str.lower()

# %%
firstFloor_const.columns
# Out:
# Index(['item', 'quantity ', 'unit price(d)', 'total cost(d)', 'total cost($)',
#        'date'],
#       dtype='str')

# %%
firstFloor_const.rename(columns={'quantity ': 'quantity', 'unit price(d)': 'unit_cost', 'total cost(d)': 'total_cost'}, inplace=True)

# %%
firstFloor_const.drop(columns='total cost($)', inplace=True)

# %%
firstFloor_const.tail()
# Out:
#                                    item quantity  unit_cost  total_cost  \
# 339                    Stone(10 Wheels)        1    14000.0     14000.0
# 340                             Cement        25        NaN         NaN
# 341                Momo Waggeh Watering        1     2100.0      2100.0
# 342      Momo Waggeh Salary(Upto May 7)        1     1000.0      1000.0
# 343  Returning Roof Concrete Materials         1     8500.0      8500.0
#
#                     date
# 339  2025-04-24 00:00:00
# 340  2025-04-24 00:00:00
# 341  2025-05-10 00:00:00
# 342  2025-05-10 00:00:00
# 343  2025-05-17 00:00:00

# %%
firstFloor_const.at[340, 'unit_cost'] = 390

# %%
firstFloor_const.at[340, 'total_cost'] = 390 * 25

# %%
firstFloor_const.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 338 entries, 0 to 343
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    object
#  1   quantity    338 non-null    object
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        337 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 23.9+ KB

# %%
firstFloor_const.tail(10)
# Out:
#                                    item quantity  unit_cost  total_cost  \
# 334                             Cement       350      385.0    134750.0
# 335              Generator Rope repair         1      150.0       150.0
# 336         Sulayman Juwara 4th Payment        1   100000.0    100000.0
# 337   Workers' Lunch for Concreting Day        1     2500.0      2500.0
# 338                     Sand(10 Wheels)        1     8000.0      8000.0
# 339                    Stone(10 Wheels)        1    14000.0     14000.0
# 340                             Cement        25      390.0      9750.0
# 341                Momo Waggeh Watering        1     2100.0      2100.0
# 342      Momo Waggeh Salary(Upto May 7)        1     1000.0      1000.0
# 343  Returning Roof Concrete Materials         1     8500.0      8500.0
#
#                     date
# 334  2025-04-23 00:00:00
# 335  2025-04-24 00:00:00
# 336  2025-04-24 00:00:00
# 337  2025-04-24 00:00:00
# 338  2025-04-24 00:00:00
# ...

# %%
firstFloor_const.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 338 entries, 0 to 343
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    object
#  1   quantity    338 non-null    object
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        337 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 23.9+ KB

# %%
#firstFloor_const.loc[len(firstFloor_const)] = ['Cement Transport', 25, 20, 500, '2025-04-24 01:00:00']

# %%
firstFloor_const.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 338 entries, 0 to 343
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    object
#  1   quantity    338 non-null    object
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        337 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 23.9+ KB

# %%
firstFloor_const[firstFloor_const['total_cost'] == 500]
# Out:
#                              item quantity  unit_cost  total_cost  \
# 1                     Wooden Pake       15       35.0       500.0
# 4       Materials Transportation         1      500.0       500.0
# 40                    Momo Waggeh        1      500.0       500.0
# 57                   Gas + Nails         1      500.0       500.0
# 72                    Nail(kg) 3"        5      100.0       500.0
# 73                Nail(kg) 2 1/2"        5      100.0       500.0
# 75       Timber 1 by 6 Transport         1      500.0       500.0
# 99           Watering the Bricks         1      500.0       500.0
# 126          Binding Wire(Bundle)        1      500.0       500.0
# 137             Cement Transport        25       20.0       500.0
# 138  Momo Waggeh arranging Bricks        1      500.0       500.0
# 141             Cement Transport        25       20.0       500.0
# 168             Cement Transport        25       20.0       500.0
# ...

# %%
firstFloor_const.to_csv('ParadiseView/out/firstFloor_const.csv', index=False)

# %%
firstFloor_Construction = pd.read_csv('ParadiseView/out/firstFloor_const.csv')

# %%
firstFloor_Construction
# Out:
#                                    item  quantity  unit_cost  total_cost  \
# 0                           1 by 2 wood        25      100.0      2500.0
# 1                           Wooden Pake        15       35.0       500.0
# 2                    3 Inches Nale(kg)          2      100.0       200.0
# 3           2 and half Inches Nale(kg)          2      100.0       200.0
# 4             Materials Transportation          1      500.0       500.0
# ..                                  ...       ...        ...         ...
# 333                    Stone(10 Wheels)         1    14000.0     14000.0
# 334                             Cement         25      390.0      9750.0
# 335                Momo Waggeh Watering         1     2100.0      2100.0
# 336      Momo Waggeh Salary(Upto May 7)         1     1000.0      1000.0
# 337  Returning Roof Concrete Materials          1     8500.0      8500.0
#
#                     date
# 0    2024-01-01 00:00:00
# 1    2024-01-01 00:00:00
# ...

# %%
firstFloor_Construction.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    str
#  1   quantity    338 non-null    int64
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        337 non-null    str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 13.3 KB

# %%
#firstFloor_Construction.loc[len(firstFloor_Construction)] = ['Cement Transport', 25, 20, 500, '2025-04-24 01:00:00']

# %%
firstFloor_Construction.head()
# Out:
#                           item  quantity  unit_cost  total_cost  \
# 0                  1 by 2 wood        25      100.0      2500.0
# 1                  Wooden Pake        15       35.0       500.0
# 2           3 Inches Nale(kg)          2      100.0       200.0
# 3  2 and half Inches Nale(kg)          2      100.0       200.0
# 4    Materials Transportation          1      500.0       500.0
#
#                   date
# 0  2024-01-01 00:00:00
# 1  2024-01-01 00:00:00
# 2  2024-01-01 00:00:00
# 3  2024-01-01 00:00:00
# 4  2024-01-01 00:00:00

# %%
firstFloor_Construction[firstFloor_Construction['item'] == 'Sadaqa']
# Out:
#        item  quantity  unit_cost  total_cost date
# 102  Sadaqa         1     3000.0      3000.0  NaN

# %%
#firstFloor_Construction.at[102, 'date'] = '2024-05-26 00:00:00'

# %%
firstFloor_Construction.loc[57]
# Out:
# item                 Gas + Nails
# quantity                        1
# unit_cost                   500.0
# total_cost                  500.0
# date          2024-03-13 00:00:00
# Name: 57, dtype: object

# %%
firstFloor_Construction.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    str
#  1   quantity    338 non-null    int64
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        338 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(1), str(1)
# memory usage: 13.3 KB

# %%
firstFloor_Construction.at[57, 'date'] = '2024-03-13 00:00:00'

# %%
firstFloor_Construction.at[46, 'date'] = '2024-03-05'

# %%
firstFloor_Construction.at[106, 'date'] = '2024-05-28'

# %%
firstFloor_Construction.at[122, 'date'] = '2024-06-14'

# %%
firstFloor_Construction.at[119, 'date'] = '2024-06-10'

# %%
firstFloor_Construction.at[134, 'date'] = '2024-08-05'

# %%
firstFloor_Construction.at[135, 'date'] = '2024-08-04'

# %%
firstFloor_Construction.at[138, 'date'] = '2024-09-04'

# %%
firstFloor_Construction.at[139, 'date'] = '2024-09-04'

# %%
firstFloor_Construction.at[146, 'date'] = '2024-09-18'

# %%
firstFloor_Construction.at[155, 'date'] = '2024-09-30'

# %%
firstFloor_Construction.at[176, 'date'] = '2024-10-28'

# %%
firstFloor_Construction.at[196, 'date'] = '2024-12-04'

# %%
firstFloor_Construction.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    str
#  1   quantity    338 non-null    int64
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        338 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(1), str(1)
# memory usage: 13.3 KB

# %%
firstFloor_Construction['date'] = pd.to_datetime(firstFloor_Construction['date']) #, dayfirst=True)

# %%
firstFloor_Construction.head()
# Out:
#                           item  quantity  unit_cost  total_cost       date
# 0                  1 by 2 wood        25      100.0      2500.0 2024-01-01
# 1                  Wooden Pake        15       35.0       500.0 2024-01-01
# 2           3 Inches Nale(kg)          2      100.0       200.0 2024-01-01
# 3  2 and half Inches Nale(kg)          2      100.0       200.0 2024-01-01
# 4    Materials Transportation          1      500.0       500.0 2024-01-01

# %%
firstFloor_Construction.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    str
#  1   quantity    338 non-null    int64
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        337 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(1), str(1)
# memory usage: 13.3 KB

# %%
#firstFloor_Construction['date'] = firstFloor_Construction['date'].dt.strftime('%m/%d/%Y')

# %%
firstFloor_Construction.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item        338 non-null    str
#  1   quantity    338 non-null    int64
#  2   unit_cost   338 non-null    float64
#  3   total_cost  338 non-null    float64
#  4   date        338 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(1), str(1)
# memory usage: 13.3 KB

# %%
firstFloor_Construction.head()
# Out:
#                           item  quantity  unit_cost  total_cost       date
# 0                  1 by 2 wood        25      100.0      2500.0 2024-01-01
# 1                  Wooden Pake        15       35.0       500.0 2024-01-01
# 2           3 Inches Nale(kg)          2      100.0       200.0 2024-01-01
# 3  2 and half Inches Nale(kg)          2      100.0       200.0 2024-01-01
# 4    Materials Transportation          1      500.0       500.0 2024-01-01

# %%
firstFloor_Construction['sub_category'] = 'Construction'
firstFloor_Construction['category'] = '1st Floor'

# %%
start_date = '01/01/2024'
end_date = '03/03/2024'
mask = firstFloor_Construction[firstFloor_Construction['date'].between(start_date, end_date)]

# %%
mask;

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between(start_date, end_date), 'exchange_rate'] = 67.50

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('03/04/2024', '03/27/2024'), 'exchange_rate'] = 68.00

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('03/28/2024', '04/23/2024'), 'exchange_rate'] = 68.20

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('04/24/2024', '05/26/2024'), 'exchange_rate'] = 68.80

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('05/27/2024', '06/01/2024'), 'exchange_rate'] = 69.70

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('06/02/2024', '09/16/2024'), 'exchange_rate'] = 69.25

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('09/17/2024', '11/11/2024'), 'exchange_rate'] = 71.00

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('1/12/2024', '03/26/2025'), 'exchange_rate'] = 71.20

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('03/27/2025', '04/07/2025'), 'exchange_rate'] = 72.25

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('04/08/2025', '04/12/2025'), 'exchange_rate'] = 72.50

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('04/13/2025', '04/18/2025'), 'exchange_rate'] = 72.60

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('04/19/2025', '05/04/2025'), 'exchange_rate'] = 72.85

# %%
firstFloor_Construction.loc[firstFloor_Construction['date'].between('05/05/2025', '05/17/2025'), 'exchange_rate'] = 72.25

# %%
firstFloor_Construction.drop(columns='data', inplace=True)

# %%
print(firstFloor_Construction.to_string())
# Out:
#                                      item  quantity  unit_cost  total_cost                 date  sub_category   category  exchange_rate
# 0                             1 by 2 wood        25      100.0      2500.0  2024-01-01 00:00:00  Construction  1st Floor          67.50
# 1                             Wooden Pake        15       35.0       500.0  2024-01-01 00:00:00  Construction  1st Floor          67.50
# 2                      3 Inches Nale(kg)          2      100.0       200.0  2024-01-01 00:00:00  Construction  1st Floor          67.50
# 3             2 and half Inches Nale(kg)          2      100.0       200.0  2024-01-01 00:00:00  Construction  1st Floor          67.50
# 4               Materials Transportation          1      500.0       500.0  2024-01-01 00:00:00  Construction  1st Floor          67.50
# 5              Floor Plan Copy/Laminating         1      550.0       550.0  2024-01-02 00:00:00  Construction  1st Floor          67.50
# ...

# %%
firstFloor_Construction.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           339 non-null    str
#  1   quantity       339 non-null    int64
#  2   unit_cost      339 non-null    float64
#  3   total_cost     339 non-null    float64
#  4   date           339 non-null    object
#  5   sub_category   339 non-null    str
#  6   category       339 non-null    str
#  7   exchange_rate  339 non-null    float64
# dtypes: float64(3), int64(1), object(1), str(3)
# memory usage: 21.3+ KB

# %%
firstFloor_Construction[firstFloor_Construction['total_cost'] == 500]
# Out:
#                              item  quantity  unit_cost  total_cost       date  \
# 1                     Wooden Pake        15       35.0       500.0 2024-01-01
# 4       Materials Transportation          1      500.0       500.0 2024-01-01
# 40                    Momo Waggeh         1      500.0       500.0 2024-02-20
# 57                   Gas + Nails          1      500.0       500.0 2024-03-13
# 72                    Nail(kg) 3"         5      100.0       500.0 2024-04-04
# 73                Nail(kg) 2 1/2"         5      100.0       500.0 2024-04-04
# 75       Timber 1 by 6 Transport          1      500.0       500.0 2024-04-07
# 99           Watering the Bricks          1      500.0       500.0 2024-05-10
# 126          Binding Wire(Bundle)         1      500.0       500.0 2024-07-04
# 137             Cement Transport         25       20.0       500.0 2024-09-04
# 138  Momo Waggeh arranging Bricks         1      500.0       500.0 2024-09-04
# ...

# %%
firstFloor_Construction.loc[len(firstFloor_Construction)] = ['Cement Transport', 25, 20, 500, '2025-04-24 01:00:00', 'Construction', '1st Floor', 72.85]

# %%
#Start from here

# %%
firstFloor_Construction.to_csv('ParadiseView/out/firstFloor_const.csv', index=False)

# %%
first_floor_const['date'] = first_floor_const['date'].dt.date

# %%
first_floor_const.to_csv('ParadiseView/out/firstFloor_const.csv', index=False)

# %%
first_floor_const = pd.read_csv('ParadiseView/out/firstFloor_const.csv')

# %%
first_floor_const
# Out:
#                                    item  quantity  unit_cost  total_cost  \
# 0                           1 by 2 wood        25      100.0      2500.0
# 1                           Wooden Pake        15       35.0       500.0
# 2                    3 Inches Nale(kg)          2      100.0       200.0
# 3           2 and half Inches Nale(kg)          2      100.0       200.0
# 4             Materials Transportation          1      500.0       500.0
# ..                                  ...       ...        ...         ...
# 334                             Cement         25      390.0      9750.0
# 335                Momo Waggeh Watering         1     2100.0      2100.0
# 336      Momo Waggeh Salary(Upto May 7)         1     1000.0      1000.0
# 337  Returning Roof Concrete Materials          1     8500.0      8500.0
# 338                    Cement Transport        25       20.0       500.0
#
#            date  sub_category   category  exchange_rate
# ...

# %%
first_floor_const[first_floor_const['sub_category'] == 'Brick Molding']
# Out:
#                              item  quantity  unit_cost  total_cost  \
# 82                         Cement        50      390.0     19500.0
# 83              Cement Transport         50       20.0      1000.0
# 87                Sand(10 Wheels)         1     7500.0      7500.0
# 90                         Cement        50      395.0     19750.0
# 91              Cement Transport         50       20.0      1000.0
# 92                Sand(10 Wheels)         1     7500.0      7500.0
# 93                         Cement        50      380.0     19000.0
# 94              Cement Transport         50       20.0      1000.0
# 97                Sand(10 Wheels)         1     7500.0      7500.0
# 100               Bricks Molding       3708        6.0     22250.0
# 133               Sand(10 Wheels)         1     7500.0      7500.0
# 135               Bricks Molding          1     7140.0      7140.0
# 138  Momo Waggeh arranging Bricks         1      500.0       500.0
# ...

# %%
first_floor_const.loc[121, ['quantity', 'total_cost']] = [62, 1860]

# %%
first_floor_const.loc[len(first_floor_const)] = ['Cemennt', 38, 415.00, 15770.00, '2024-06-11', 'Brick Molding', '1st Floor', 71.20]

# %%
first_floor_const.loc[len(first_floor_const)] = ['Cemennt Transport', 38, 30, 1140.00, '2024-06-11', 'Brick Molding', '1st Floor', 71.20]

# %%
first_floor_const.loc[138, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[133, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[135, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[82, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[83, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[90, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[91, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[93, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[94, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[87, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[92, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[97, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.loc[100, 'sub_category'] = 'Brick Molding'

# %%
first_floor_const.drop(columns='sub-category', inplace=True)

# %%
print(first_floor_const.to_string())
# Out:
#                                      item  quantity  unit_cost  total_cost       date   sub_category   category  exchange_rate
# 0                             1 by 2 wood        25      100.0      2500.0 2024-01-01   Construction  1st Floor          67.50
# 1                             Wooden Pake        15       35.0       500.0 2024-01-01   Construction  1st Floor          67.50
# 2                      3 Inches Nale(kg)          2      100.0       200.0 2024-01-01   Construction  1st Floor          67.50
# 3             2 and half Inches Nale(kg)          2      100.0       200.0 2024-01-01   Construction  1st Floor          67.50
# 4               Materials Transportation          1      500.0       500.0 2024-01-01   Construction  1st Floor          67.50
# 5              Floor Plan Copy/Laminating         1      550.0       550.0 2024-01-02   Construction  1st Floor          67.50
# ...

# %%
first_floor_const.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           342 non-null    str
#  1   quantity       342 non-null    int64
#  2   unit_cost      342 non-null    float64
#  3   total_cost     342 non-null    float64
#  4   date           342 non-null    datetime64[us]
#  5   sub_category   342 non-null    str
#  6   category       342 non-null    str
#  7   exchange_rate  342 non-null    float64
# dtypes: datetime64[us](1), float64(3), int64(1), str(3)
# memory usage: 21.5 KB

# %%
first_floor_const['date'] = pd.to_datetime(first_floor_const['date'])

# %%
first_floor_const.head()
# Out:
#                           item  quantity  unit_cost  total_cost       date  \
# 0                  1 by 2 wood        25      100.0      2500.0 2024-01-01
# 1                  Wooden Pake        15       35.0       500.0 2024-01-01
# 2           3 Inches Nale(kg)          2      100.0       200.0 2024-01-01
# 3  2 and half Inches Nale(kg)          2      100.0       200.0 2024-01-01
# 4    Materials Transportation          1      500.0       500.0 2024-01-01
#
#    sub_category   category  exchange_rate
# 0  Construction  1st Floor           67.5
# 1  Construction  1st Floor           67.5
# 2  Construction  1st Floor           67.5
# 3  Construction  1st Floor           67.5
# 4  Construction  1st Floor           67.5

# %%
first_floor_const.to_csv('ParadiseView/out/firstFloor_const.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 first_floor_const.to_csv('ParadiseView/out/firstFloor_const.csv', index=False)
#
# NameError: name 'first_floor_const' is not defined

# %%
first_floor_const = pd.read_csv('ParadiseView/out/firstFloor_const.csv')

# %%
print(first_floor_const.to_string())
# Out:
#                                     item  quantity  unit_cost  total_cost        date     sub_category   category  exchange_rate
# 0                            1 by 2 wood        25      100.0      2500.0  2024-01-01     Construction  1st Floor          67.50
# 1                            Wooden Pake        15       35.0       500.0  2024-01-01     Construction  1st Floor          67.50
# 2                     3 Inches Nale(kg)          2      100.0       200.0  2024-01-01     Construction  1st Floor          67.50
# 3            2 and half Inches Nale(kg)          2      100.0       200.0  2024-01-01     Construction  1st Floor          67.50
# 4              Materials Transportation          1      500.0       500.0  2024-01-01     Construction  1st Floor          67.50
# 5             Floor Plan Copy/Laminating         1      550.0       550.0  2024-01-02     Construction  1st Floor          67.50
# ...

# %%
first_floor_const.iloc[258:338, 5:6] = 'Roof Concreting'

# %%
first_floor_const.at[263, 'sub_category'] = 'Construction'

# %%
first_floor_const.at[338, 'sub_category'] = 'Roof Concreting'

# %%
first_floor_const['item'] = first_floor_const['item'].str.replace('-', '', regex=True)

# %%
first_floor_const['item'] = first_floor_const['item'].str.replace('---Momo', 'Momo', regex=True)

# %%
first_floor_const.at[317, 'item'] = 'Momo Waggeh Putting Sand inside'

# %%
first_floor_const.at[285, 'item'] = '2nd Floor Architect Transport'

# %%
first_floor_const.at[302, 'item'] = 'Gas for Generator'

# %%
first_floor_const.iloc[[13, 42, 58, 87, 92, 117, 119, 152, 187, 236, 267, 295, 300, 301, 303, 309, 326, 332], 0:1] = 'Sand (10 Wheel)'

# %%
first_floor_const.to_csv('ParadiseView/out/firstFloor_const.csv', index=False)

# %%
pd.read_csv('ParadiseView/out/firstFloor_const.csv').info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           342 non-null    str
#  1   quantity       342 non-null    int64
#  2   unit_cost      342 non-null    float64
#  3   total_cost     342 non-null    float64
#  4   date           342 non-null    str
#  5   sub_category   342 non-null    str
#  6   category       342 non-null    str
#  7   exchange_rate  342 non-null    float64
# dtypes: float64(3), int64(1), str(4)
# memory usage: 21.5 KB
