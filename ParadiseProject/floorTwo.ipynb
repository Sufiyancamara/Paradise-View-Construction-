# %%
import pandas as pd
import numpy as np

# %%
secondfloor_brick = pd.read_csv('ParadiseView/out/df_secondfloor_bricks.csv')

# %%
secondfloor_const = pd.read_csv('ParadiseView/out/df_secondfloor_const.csv')

# %%
secondfloor_roof = pd.read_csv('ParadiseView/out/df_secondfloor_roof.csv')

# %%
print(secondfloor_brick.to_string())
# Out:
#                                  item  quantity  unit_cost  total_cost        date   sub_category   category  exchange_rate
# 0           Clearing Momo Haja's plot       1.0     3500.0      3500.0  2025-04-14  Brick Molding  2nd Floor           71.2
# 1   2nd Floor Plan Consultation(gas)        1.0      600.0       600.0  2025-04-15  Brick Molding  2nd Floor           71.2
# 2                             Cement       25.0      390.0      9750.0  2025-04-16  Brick Molding  2nd Floor           71.2
# 3                   Cement Transport       25.0       20.0       500.0  2025-04-16  Brick Molding  2nd Floor           71.2
# 4                       Sand(10Wheel)       1.0     8000.0      8000.0  2025-04-19  Brick Molding  2nd Floor           71.2
# 5                       Sand Wave Fee       1.0       80.0        80.0  2025-04-19  Brick Molding  2nd Floor           71.2
# ...

# %%
print(secondfloor_const.to_string())
# Out:
#                                            item  quantity  unit_cost  total_cost        date  sub_category   category  exchange_rate
# 0                       Rope for Lifting Bricks         1      400.0       400.0  2025-08-28  Construction  2nd Floor           73.5
# 1                                 Iron Rod 12mm        70      550.0     38500.0  2025-08-30  Construction  2nd Floor           73.5
# 2                                  Iron Rod 6mm        40      150.0      6000.0  2025-08-30  Construction  2nd Floor           73.5
# 3                                   Wheelbarrow         1     2800.0      2800.0  2025-08-30  Construction  2nd Floor           73.5
# 4                            Binding Wire(Roll)         2      500.0      1000.0  2025-08-30  Construction  2nd Floor           73.5
# 5                            Materials Transpot         1     1000.0      1000.0  2025-08-30  Construction  2nd Floor           73.5
# ...

# %%
print(secondfloor_roof.to_string())
# Out:
#                                      item  quantity  unit_cost  total_cost        date     sub_category   category  exchange_rate
# 0                                1/2 wood     100.0      100.0     10000.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 1                     1/2 Wood Transport        1.0     1000.0      1000.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 2                  Concrete Nail 2 1/2 in       5.0      200.0      1000.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 3                      Concrete Nail 2 in      45.0       30.0      1350.0  2025-12-05  Roof Concreting  2nd Floor          74.25
# 4                                1/2 Wood      35.0      100.0      3500.0  2025-12-06  Roof Concreting  2nd Floor          74.25
# 5                                1/6 Wood       2.0      350.0       700.0  2025-12-06  Roof Concreting  2nd Floor          74.25
# ...

# %%
secondfloor = pd.concat([secondfloor_brick, secondfloor_const, secondfloor_roof], axis=0, ignore_index=True)

# %%
secondfloor
# Out:
#                                   item  quantity  unit_cost  total_cost  \
# 0            Clearing Momo Haja's plot       1.0     3500.0      3500.0
# 1    2nd Floor Plan Consultation(gas)        1.0      600.0       600.0
# 2                              Cement       25.0      390.0      9750.0
# 3                    Cement Transport       25.0       20.0       500.0
# 4                        Sand(10Wheel)       1.0     8000.0      8000.0
# ..                                 ...       ...        ...         ...
# 218   2/3 Wood Rental 2Days Extension      375.0        5.0      5625.0
# 219   Acrojack Rental 2Days Extension      475.0        2.5      3565.0
# 220            Carpenter Sana Payment        1.0     1500.0      1500.0
# 221             Bubacarr Faye Payment        1.0    12000.0     12000.0
# 222  Ali moving the Woods  to the Room       1.0      481.0       481.0
#
#            date     sub_category   category  exchange_rate
# ...

# %%
print(secondfloor.to_string())
# Out:
#                                            item  quantity  unit_cost  total_cost        date     sub_category   category  exchange_rate
# 0                     Clearing Momo Haja's plot       1.0     3500.0      3500.0  2025-04-14    Brick Molding  2nd Floor          71.20
# 1             2nd Floor Plan Consultation(gas)        1.0      600.0       600.0  2025-04-15    Brick Molding  2nd Floor          71.20
# 2                                       Cement       25.0      390.0      9750.0  2025-04-16    Brick Molding  2nd Floor          71.20
# 3                             Cement Transport       25.0       20.0       500.0  2025-04-16    Brick Molding  2nd Floor          71.20
# 4                                 Sand(10Wheel)       1.0     8000.0      8000.0  2025-04-19    Brick Molding  2nd Floor          71.20
# 5                                 Sand Wave Fee       1.0       80.0        80.0  2025-04-19    Brick Molding  2nd Floor          71.20
# ...

# %%
secondfloor['total_cost'].sum()
# Out:
# np.float64(2128055.0)

# %%
secondfloor.to_csv('ParadiseView/clean/floorTwo.csv', index=False)

# %%
pd.read_csv('ParadiseView/clean/floorTwo.csv')
# Out:
#                                   item  quantity  unit_cost  total_cost  \
# 0            Clearing Momo Haja's plot       1.0     3500.0      3500.0
# 1    2nd Floor Plan Consultation(gas)        1.0      600.0       600.0
# 2                              Cement       25.0      390.0      9750.0
# 3                    Cement Transport       25.0       20.0       500.0
# 4                        Sand(10Wheel)       1.0     8000.0      8000.0
# ..                                 ...       ...        ...         ...
# 218   2/3 Wood Rental 2Days Extension      375.0        5.0      5625.0
# 219   Acrojack Rental 2Days Extension      475.0        2.5      3565.0
# 220            Carpenter Sana Payment        1.0     1500.0      1500.0
# 221             Bubacarr Faye Payment        1.0    12000.0     12000.0
# 222  Ali moving the Woods  to the Room       1.0      481.0       481.0
#
#            date     sub_category   category  exchange_rate
# ...
