# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_pview = pd.read_excel('ParadiseView/clean/df_paradiseView.xlsx')

# %%
df_pview
# Out:
#                                     item  quantity  unit_cost  total_cost  \
# 0          Paradise View Plot: 20m x 25m       1.0   750000.0      750000
# 1                    Physical Plan Guy 1       1.0     1500.0        1500
# 2                    Physical Plan Guy 2       1.0     1000.0        1000
# 3                           MoneyTra Fee       1.0      490.0         490
# 4                    Physical Plan Guy 2       1.0     2000.0        2000
# ..                                   ...       ...        ...         ...
# 825                              Cement        3.0      455.0        1365
# 826                    Cement Transport        3.0       20.0          60
# 827  Access- no Change for Bubacarr Faye       1.0       40.0          40
# 828                 Rebuilding the Fence       1.0     2500.0        2500
# 829                Ali Watering the Roof       1.0     2000.0        2000
#
#           date     sub_category   category  exchange_rate
# ...

# %%
# total cost accross floors
stages_expense = df_pview.groupby('category')['total_cost'].sum()

# %%
stages_expense
# Out:
# category
# 1st Floor          3075725
# 2nd Floor          2128055
# 3rd Floor          2125229
# Buying              764990
# Preconstruction     267135
# Name: total_cost, dtype: int64
