# %%
import pandas as pd
import numpy as np

# %%
cost = pd.read_csv('ParadiseView/out/df_cost.csv')

# %%
fencing = pd.read_csv('ParadiseView/out/df_fencing.csv')

# %%
borehole = pd.read_csv('ParadiseView/out/df_borehole_drill.csv')

# %%
cont_consul = pd.read_csv('ParadiseView/out/df_contractor_consul.csv')

# %%
otherExp = pd.read_csv('ParadiseView/out/df_otherExp_clean.csv')

# %%
cost
# Out:
#                              item  quantity  unit_cost  total_cost  \
# 0   Paradise View Plot: 20m x 25m         1     750000      750000
# 1             Physical Plan Guy 1         1       1500        1500
# 2             Physical Plan Guy 2         1       1000        1000
# 3                    MoneyTra Fee         1        490         490
# 4             Physical Plan Guy 2         1       2000        2000
# 5                      GTBank Fee         1       5000        5000
# 6                     Gas for Car         1        500         500
# 7             Chief Area Council          1       2000        2000
# 8                     Gas for Car         1        500         500
# 9               Lady Filled Forms         1        400         400
# 10                  Sukuta Alkalo         1       1500        1500
# 11                            Gas         1        100         100
#
#           date  sub_category category  exchange_rate
# ...

# %%
fencing
# Out:
#                       item  quantity  unit_cost  total_cost        date  \
# 0            Cutting Trees         1      10000       10000  2020-04-30
# 1         Big Trip of Sand         1       7500        7500  2020-04-30
# 2       Small Trip of Sand         1       4000        4000  2020-04-30
# 3                  Cement         40        285       11400  2020-05-06
# 4        Cement Transport          1        600         600  2020-05-06
# 5       Wheelbarrow Rental         1        200         200  2020-05-06
# 6           Molding Bricks      1370          5        6850  2020-05-06
# 7       Water for Molding          1       1000        1000  2020-05-06
# 8       Gas for Transport          1        450         450  2020-05-06
# 9           Police Ticket          1        200         200  2020-04-29
# 10        Trip of Pebbles          1       3500        3500  2020-05-08
# 11                 Cement         25        285        7125  2020-05-08
# ...

# %%
borehole
# Out:
#                                      item  quantity  unit_cost  total_cost  \
# 0                           Bore Drilling       1.0    95000.0     95000.0
# 1                               Carpenter       1.0     6500.0      6500.0
# 2                                Kaye Rod      34.0      180.0      6120.0
# 3         Polycarbonate Roof Panel(Packs)       2.5     4300.0     10750.0
# 4                            Big Nale(kg)       3.0      100.0       300.0
# 5                       Small Nale(Packs)       3.0      350.0      1050.0
# 6                          Wood for Doors       5.0      300.0      1500.0
# 7  Cutting Mango Branch and Moving Bricks       1.0     1600.0      1600.0
# 8                         Delivering Guys       1.0      800.0       800.0
# 9                                Residual       1.0     2380.0      2380.0
#
#          date       sub_category         category  exchange_rate
# 0  2023-06-24  Borehole Drilling  Preconstruction           63.0
# ...

# %%
cont_consul
# Out:
#                      item  quantity  unit_cost  total_cost        date  \
# 0  Consulting Contractors         1       4000        4000  2023-09-25
# 1       Clearing the Area         1       8000        8000  2023-12-21
# 2         Transportation          1       2000        2000  2023-12-21
# 3            Bubacarr Fai         1       2000        2000  2023-12-20
#
#               sub_category         category  exchange_rate
# 0  Contractor Consultation  Preconstruction           61.5
# 1  Contractor Consultation  Preconstruction           64.0
# 2  Contractor Consultation  Preconstruction           64.0
# 3  Contractor Consultation  Preconstruction           64.0

# %%
otherExp
# Out:
#             item  quantity  unit_cost  total_cost        date sub_category  \
# 0      Papa Jara         1     2000.0      2000.0  2020-03-23      Fencing
# 1  Bubacarr Faye         1     1500.0      1500.0  2020-04-29      Fencing
# 2      Papa Jara         1     2000.0      2000.0  2020-05-23      Fencing
# 3  Bubacarr Faye         1     2000.0      2000.0  2020-05-23      Fencing
# 4      Papa Jara         1     2500.0      2500.0  2020-04-23      Fencing
# 5  Bubacarr Faye         1     2500.0      2500.0  2020-04-23      Fencing
#
#           category  exchange_rate
# 0  Preconstruction           49.0
# 1  Preconstruction           49.0
# 2  Preconstruction           49.0
# 3  Preconstruction           49.0
# 4  Preconstruction           49.0
# 5  Preconstruction           49.0

# %%
cost_to_precons = pd.concat([cost, otherExp, fencing, borehole, cont_consul], axis=0, ignore_index=True)

# %%
print(cost_to_precons.to_string())
# Out:
#                                       item  quantity  unit_cost  total_cost        date             sub_category         category  exchange_rate
# 0            Paradise View Plot: 20m x 25m       1.0   750000.0    750000.0  2019-08-03                     Cost           Buying           49.0
# 1                      Physical Plan Guy 1       1.0     1500.0      1500.0  2019-08-09             Registration           Buying           49.0
# 2                      Physical Plan Guy 2       1.0     1000.0      1000.0  2019-12-17             Registration           Buying           49.0
# 3                             MoneyTra Fee       1.0      490.0       490.0  2020-02-06             Registration           Buying           49.0
# 4                      Physical Plan Guy 2       1.0     2000.0      2000.0  2020-02-07             Registration           Buying           49.0
# ...

# %%
cost_to_precons.to_csv('ParadiseView/clean/cost_to_preconstruction.csv', index=False)
