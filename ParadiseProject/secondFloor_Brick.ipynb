# %%
import numpy as np
import pandas as pd

# %%
second_floor_bmolding = pd.read_excel('ParadiseView/Paradise View Expenditures 4.xlsx', skiprows=4, sheet_name='2nd Floor Brick Molding')

# %%
second_floor_bmolding
# Out:
#                                  ITEM  QUANTITY   UNIT PRICE(D)  \
# 0           Clearing Momo Haja's plot        1.0         3500.0
# 1   2nd Floor Plan Consultation(gas)         1.0          600.0
# 2                             Cement        25.0          390.0
# 3                   Cement Transport        25.0           20.0
# 4                                 NaN        NaN            NaN
# 5                       Sand(10Wheel)        1.0         8000.0
# 6                       Sand Wave Fee        1.0           80.0
# 7                   Gas for Generator        1.0          400.0
# 8                       Sand(10Wheel)        1.0         8000.0
# 9          Waggeh-putting sand inside        1.0         1300.0
# 10                                NaN        NaN            NaN
# 11                      50 meter Hose        1.0         1600.0
# 12                                NaN        NaN            NaN
# 13                            Cement       150.0          465.0
# ...

# %%
second_floor_bmolding.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ITEM           29 non-null     str
#  1   QUANTITY       28 non-null     float64
#  2   UNIT PRICE(D)  28 non-null     float64
#  3   TOTAL COST(D)  29 non-null     float64
#  4   Date           28 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(3), str(1)
# memory usage: 1.4 KB

# %%
second_floor_bmolding = second_floor_bmolding.dropna()

# %%
second_floor_bmolding
# Out:
#                                  ITEM  QUANTITY   UNIT PRICE(D)  \
# 0           Clearing Momo Haja's plot        1.0         3500.0
# 1   2nd Floor Plan Consultation(gas)         1.0          600.0
# 2                             Cement        25.0          390.0
# 3                   Cement Transport        25.0           20.0
# 5                       Sand(10Wheel)        1.0         8000.0
# 6                       Sand Wave Fee        1.0           80.0
# 7                   Gas for Generator        1.0          400.0
# 8                       Sand(10Wheel)        1.0         8000.0
# 9          Waggeh-putting sand inside        1.0         1300.0
# 11                      50 meter Hose        1.0         1600.0
# 13                            Cement       150.0          465.0
# 14                  Cement Transport       150.0           20.0
# 15                     Sand(10Wheel)         1.0         8000.0
# 16                     Sand(10Wheel)         1.0         8000.0
# ...

# %%
second_floor_bmolding.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 28 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ITEM           28 non-null     str
#  1   QUANTITY       28 non-null     float64
#  2   UNIT PRICE(D)  28 non-null     float64
#  3   TOTAL COST(D)  28 non-null     float64
#  4   Date           28 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(3), str(1)
# memory usage: 1.3 KB

# %%
second_floor_bmolding.columns
# Out:
# Index(['ITEM', 'QUANTITY ', 'UNIT PRICE(D)', 'TOTAL COST(D)', 'Date'], dtype='str')

# %%
second_floor_bmolding.columns = second_floor_bmolding.columns.str.lower()

# %%
second_floor_bmolding.columns
# Out:
# Index(['item', 'quantity ', 'unit price(d)', 'total cost(d)', 'date'], dtype='str')

# %%
second_floor_bmolding.rename(columns={'quantity ': 'quantity', 'unit price(d)': 'unit_cost', 'total cost(d)': 'total_cost'}, inplace=True)

# %%
second_floor_bmolding.columns
# Out:
# Index(['item', 'quantity', 'unit_cost', 'total_cost', 'date'], dtype='str')

# %%
second_floor_bmolding
# Out:
#                                  item  quantity  unit_cost  total_cost  \
# 0           Clearing Momo Haja's plot       1.0     3500.0      3500.0
# 1   2nd Floor Plan Consultation(gas)        1.0      600.0       600.0
# 2                             Cement       25.0      390.0      9750.0
# 3                   Cement Transport       25.0       20.0       500.0
# 5                       Sand(10Wheel)       1.0     8000.0      8000.0
# 6                       Sand Wave Fee       1.0       80.0        80.0
# 7                   Gas for Generator       1.0      400.0       400.0
# 8                       Sand(10Wheel)       1.0     8000.0      8000.0
# 9          Waggeh-putting sand inside       1.0     1300.0      1300.0
# 11                      50 meter Hose       1.0     1600.0      1600.0
# 13                            Cement      150.0      465.0     69750.0
# 14                  Cement Transport      150.0       20.0      3000.0
# ...

# %%
second_floor_bmolding['sub_category'] = 'Brick Molding'
second_floor_bmolding['category'] = '2nd Floor'

# %%
second_floor_bmolding.columns
# Out:
# Index(['item', 'quantity', 'unit_cost', 'total_cost', 'date', 'sub_category',
#        'category'],
#       dtype='str')

# %%
second_floor_bmolding.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 28 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   item          28 non-null     str
#  1   quantity      28 non-null     float64
#  2   unit_cost     28 non-null     float64
#  3   total_cost    28 non-null     float64
#  4   date          28 non-null     datetime64[us]
#  5   sub_category  28 non-null     str
#  6   category      28 non-null     str
# dtypes: datetime64[us](1), float64(3), str(3)
# memory usage: 1.8 KB

# %%
second_floor_bmolding['exchange_rate'] = 0.00

# %%
second_floor_bmolding.loc[:11, 'exchange_rate'] = 71.20

# %%
second_floor_bmolding.loc[12:, 'exchange_rate'] = 69.00

# %%
second_floor_bmolding.at[16, 'exchange_rate'] = 68.90

# %%
second_floor_bmolding.at[18, 'exchange_rate'] = 68.90

# %%
second_floor_bmolding
# Out:
#                                  item  quantity  unit_cost  total_cost  \
# 0           Clearing Momo Haja's plot       1.0     3500.0      3500.0
# 1   2nd Floor Plan Consultation(gas)        1.0      600.0       600.0
# 2                             Cement       25.0      390.0      9750.0
# 3                   Cement Transport       25.0       20.0       500.0
# 5                       Sand(10Wheel)       1.0     8000.0      8000.0
# 6                       Sand Wave Fee       1.0       80.0        80.0
# 7                   Gas for Generator       1.0      400.0       400.0
# 8                       Sand(10Wheel)       1.0     8000.0      8000.0
# 9          Waggeh-putting sand inside       1.0     1300.0      1300.0
# 11                      50 meter Hose       1.0     1600.0      1600.0
# 13                            Cement      150.0      465.0     69750.0
# 14                  Cement Transport      150.0       20.0      3000.0
# ...

# %%
second_floor_bmolding.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 28 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           28 non-null     str
#  1   quantity       28 non-null     float64
#  2   unit_cost      28 non-null     float64
#  3   total_cost     28 non-null     float64
#  4   date           28 non-null     datetime64[us]
#  5   sub_category   28 non-null     str
#  6   category       28 non-null     str
#  7   exchange_rate  28 non-null     float64
# dtypes: datetime64[us](1), float64(4), str(3)
# memory usage: 3.0 KB

# %%
second_floor_bmolding.to_csv('ParadiseView/out/df_secondfloor_bmolding.csv', index=False)

# %%
pd.read_csv('ParadiseView/out/df_secondfloor_bmolding.csv')
# Out:
#                                  item  quantity  unit_cost  total_cost  \
# 0           Clearing Momo Haja's plot       1.0     3500.0      3500.0
# 1   2nd Floor Plan Consultation(gas)        1.0      600.0       600.0
# 2                             Cement       25.0      390.0      9750.0
# 3                   Cement Transport       25.0       20.0       500.0
# 4                       Sand(10Wheel)       1.0     8000.0      8000.0
# 5                       Sand Wave Fee       1.0       80.0        80.0
# 6                   Gas for Generator       1.0      400.0       400.0
# 7                       Sand(10Wheel)       1.0     8000.0      8000.0
# 8          Waggeh-putting sand inside       1.0     1300.0      1300.0
# 9                       50 meter Hose       1.0     1600.0      1600.0
# 10                            Cement      150.0      465.0     69750.0
# 11                  Cement Transport      150.0       20.0      3000.0
# ...
