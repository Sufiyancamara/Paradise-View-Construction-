# %%
import numpy as np
import pandas as pd
from datetime import datetime, date

# %%
contractor_consul = pd.read_excel('ParadiseView/Paradise View Expenditures 4.xlsx', sheet_name='Consultation', skiprows= 4)

# %%
contractor_consul
# Out:
#                        ITEM                        QUANTITY   UNIT PRICE(D)  \
# 0    Consulting Contractors                                1           4000
# 1                       NaN                              NaN            NaN
# 2                     Total                              NaN           4000
# 3                       NaN                              NaN            NaN
# 4   1 Dollar = 61.5 Dalasis                              NaN            NaN
# 5                       NaN                              NaN            NaN
# 6                       NaN                              NaN            NaN
# 7                       NaN                              NaN            NaN
# 8                       NaN  Preparing Land for Construction            NaN
# 9                      ITEM                        QUANTITY   UNIT PRICE(D)
# 10        Clearing the Area                                1           8000
# ...

# %%
contractor_consul.dropna(thresh = (len(contractor_consul.columns) - 2), axis=0, inplace=True)

# %%
contractor_consul
# Out:
#                       ITEM  QUANTITY   UNIT PRICE(D)        TOTAL COST(D)  \
# 0   Consulting Contractors          1           4000                 4000
# 2                    Total        NaN           4000                 4000
# 9                     ITEM  QUANTITY   UNIT PRICE(D)        TOTAL COST(D)
# 10       Clearing the Area          1           8000                 8000
# 11         Transportation           1           2000                 2000
# 12                   Total        NaN          10000                10000
# 21                     WHO  AMOUNT(D)      AMOUNT($)                 DATE
# 22            Bubacarr Fai       2000          31.25  2023-12-20 00:00:00
#
#      COST($)                 DATE
# 0   65.04065  2023-09-25 00:00:00
# 2   65.04065                  NaN
# 9    COST($)                 DATE
# 10       125  2023-12-21 00:00:00
# 11     31.25  2023-12-21 00:00:00
# 12    156.25                  NaN
# 21       NaN                  NaN
# ...

# %%
contractor_consul = contractor_consul.drop(index=[2,9,12,21])

# %%
contractor_consul
# Out:
#                       ITEM QUANTITY  UNIT PRICE(D)        TOTAL COST(D)  \
# 0   Consulting Contractors         1          4000                 4000
# 10       Clearing the Area         1          8000                 8000
# 11         Transportation          1          2000                 2000
# 22            Bubacarr Fai      2000         31.25  2023-12-20 00:00:00
#
#      COST($)                 DATE
# 0   65.04065  2023-09-25 00:00:00
# 10       125  2023-12-21 00:00:00
# 11     31.25  2023-12-21 00:00:00
# 22       NaN                  NaN

# %%
contractor_consul.drop(columns='COST($)')
# Out:
#                       ITEM QUANTITY  UNIT PRICE(D)        TOTAL COST(D)  \
# 0   Consulting Contractors         1          4000                 4000
# 10       Clearing the Area         1          8000                 8000
# 11         Transportation          1          2000                 2000
# 22            Bubacarr Fai      2000         31.25  2023-12-20 00:00:00
#
#                    DATE  QUANTITY
# 0   2023-09-25 00:00:00       NaN
# 10  2023-12-21 00:00:00       NaN
# 11  2023-12-21 00:00:00       NaN
# 22                  NaN       1.0

# %%
contractor_consul.columns =contractor_consul.columns.str.lower()
contractor_consul.rename(columns={'quantity ': 'quantity', 'unit price(d)': 'unit_cost', 'total cost(d)': 'total_cost'}, inplace=True)

# %%
contractor_consul.loc[22, 'date'] ='2023-12-20 00:00:00'

# %%
 contractor_consul.drop(columns='cost($)', inplace=True)

# %%
contractor_consul
# Out:
#                       item quantity unit_cost total_cost                 date
# 0   Consulting Contractors        1      4000       4000  2023-09-25 00:00:00
# 10       Clearing the Area        1      8000       8000  2023-12-21 00:00:00
# 11         Transportation         1      2000       2000  2023-12-21 00:00:00
# 22            Bubacarr Fai        1      2000       2000  2023-12-20 00:00:00

# %%
contractor_consul['date'] = pd.to_datetime(contractor_consul['date'])

# %%
contractor_consul['date'] = contractor_consul['date'].dt.strftime('%m/%d/%Y')

# %%
contractor_consul['sub_category'] = 'Contractor Consultation'
contractor_consul['category'] = 'Preconstruction'

# %%
contractor_consul['exchange_rate'] = 61.50

# %%
contractor_consul.loc[1:, 'exchange_rate'] = 64.00

# %%
contractor_consul
# Out:
#                      item  quantity  unit_cost  total_cost       date  \
# 0  Consulting Contractors         1       4000        4000 2023-09-25
# 1       Clearing the Area         1       8000        8000 2023-12-21
# 2         Transportation          1       2000        2000 2023-12-21
# 3            Bubacarr Fai         1       2000        2000 2023-12-20
#
#               sub_category         category  exchange_rate
# 0  Contractor Consultation  Preconstruction           61.5
# 1  Contractor Consultation  Preconstruction           64.0
# 2  Contractor Consultation  Preconstruction           64.0
# 3  Contractor Consultation  Preconstruction           64.0

# %%
contractor_consul['date'] = pd.to_datetime(contractor_consul['date'])

# %%
contractor_consul.to_csv('ParadiseView/out/df_contractor_consul.csv', index=False)

# %%
contractor_consul = pd.read_csv('ParadiseView/out/df_contractor_consul.csv')

# %%
contractor_consul
# Out:
#                      item  quantity  unit_cost  total_cost       date  \
# 0  Consulting Contractors         1       4000        4000 2023-09-25
# 1       Clearing the Area         1       8000        8000 2023-12-21
# 2         Transportation          1       2000        2000 2023-12-21
# 3            Bubacarr Fai         1       2000        2000 2023-12-20
#
#               sub_category         category  exchange_rate
# 0  Contractor Consultation  Preconstruction           61.5
# 1  Contractor Consultation  Preconstruction           64.0
# 2  Contractor Consultation  Preconstruction           64.0
# 3  Contractor Consultation  Preconstruction           64.0
