# %%
import pandas as pd
import numpy as np

# %%
thirdfloor_roof = pd.read_excel('para/Paradise View.xlsx', sheet_name='3rd Floor Roof Concrete ', skiprows=1)

# %%
thirdfloor_roof
# Out:
#                          ITEM  QUALITY   UNIT PRICE(D)  TOTAL COST(D)  \
# 0                 Ali Salary        1.0         5500.0         5500.0
# 1                    1/2 Wood     200.0          100.0        20000.0
# 2         1/2 Wood Transport        1.0          800.0          800.0
# 3    2/3 Wood Rentals(25Days)     150.0            5.5        20625.0
# 4         2/3 Woods Transport       1.0         1000.0         1000.0
# ..                        ...       ...            ...            ...
# 97                        NaN       NaN            NaN            NaN
# 98                        NaN       NaN            NaN            NaN
# 99                        NaN       NaN            NaN            NaN
# 100                       NaN       NaN            NaN            NaN
# 101                       NaN       NaN            NaN            NaN
#
#           DATE  Unnamed: 5       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# ...

# %%
thirdfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ITEM           77 non-null     str
#  1   QUALITY        76 non-null     float64
#  2   UNIT PRICE(D)  76 non-null     float64
#  3   TOTAL COST(D)  77 non-null     float64
#  4   DATE           76 non-null     datetime64[us]
#  5   Unnamed: 5     0 non-null      float64
#  6   Unnamed: 6     12 non-null     str
#  7   Unnamed: 7     8 non-null      object
#  8   Unnamed: 8     11 non-null     object
#  9   Unnamed: 9     8 non-null      object
#  10  Unnamed: 10    7 non-null      object
# dtypes: datetime64[us](1), float64(4), object(4), str(2)
# memory usage: 8.9+ KB

# %%
thirdfloor_roof.dropna(how='all', axis=1, inplace=True)

# %%
thirdfloor_roof
# Out:
#                          ITEM  QUALITY   UNIT PRICE(D)  TOTAL COST(D)  \
# 0                 Ali Salary        1.0         5500.0         5500.0
# 1                    1/2 Wood     200.0          100.0        20000.0
# 2         1/2 Wood Transport        1.0          800.0          800.0
# 3    2/3 Wood Rentals(25Days)     150.0            5.5        20625.0
# 4         2/3 Woods Transport       1.0         1000.0         1000.0
# ..                        ...       ...            ...            ...
# 97                        NaN       NaN            NaN            NaN
# 98                        NaN       NaN            NaN            NaN
# 99                        NaN       NaN            NaN            NaN
# 100                       NaN       NaN            NaN            NaN
# 101                       NaN       NaN            NaN            NaN
#
#           DATE       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# ...

# %%
thirdfloor_roof = thirdfloor_roof.drop(columns=thirdfloor_roof.loc[:, 'Unnamed: 6' : 'Unnamed: 10'].columns)

# %%
thirdfloor_roof.dropna(thresh=3, axis=0, inplace=True)

# %%
thirdfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ITEM           76 non-null     str
#  1   QUALITY        76 non-null     float64
#  2   UNIT PRICE(D)  76 non-null     float64
#  3   TOTAL COST(D)  76 non-null     float64
#  4   DATE           76 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(3), str(1)
# memory usage: 3.1 KB

# %%
thirdfloor_roof.columns = thirdfloor_roof.columns.str.lower()

# %%
thirdfloor_roof.columns
# Out:
# Index(['item', 'quality ', 'unit price(d)', 'total cost(d)', 'date'], dtype='str')

# %%
thirdfloor_roof.rename(columns={'quality ': 'quantity', 'unit price(d)': 'unit_cost', 'total cost(d)': 'total_cost'}, inplace=True)

# %%
thirdfloor_roof['sub_category'] = 'Roof Concreting'
thirdfloor_roof['category'] = '3rd Floor'

# %%
thirdfloor_roof.loc[1, 'date'] = pd.to_datetime('2026-05-01')

# %%
thirdfloor_roof['exchange_rate'] = np.where(thirdfloor_roof['date'].between('2026-04-29', '2026-05-15'), 73.80, 0)

# %%
thirdfloor_roof['exchange_rate'] = np.where(thirdfloor_roof['date'].between('2026-05-16', '2026-05-17'), 73.75, thirdfloor_roof['exchange_rate'])

# %%
thirdfloor_roof['exchange_rate'] = np.where(thirdfloor_roof['date'].between('2026-05-18', '2026-05-20'), 73.85, thirdfloor_roof['exchange_rate'])

# %%
thirdfloor_roof['exchange_rate'] = np.where(thirdfloor_roof['date'].between('2026-05-21', '2026-06-10'), 73.75, thirdfloor_roof['exchange_rate'])

# %%
thirdfloor_roof['exchange_rate'] = np.where(thirdfloor_roof['date'].between('2026-06-11', '2026-06-16'), 74.00, thirdfloor_roof['exchange_rate'])

# %%
thirdfloor_roof.loc[len(thirdfloor_roof)] = ['Ali Watering the Roof', 1, 2000, 2000, pd.to_datetime('2026-07-03'), 'Roof Concreting', '3rd Floor', 74.00]

# %%
print(thirdfloor_roof.to_string())
# Out:
#                                           item  quantity  unit_cost  total_cost       date     sub_category   category  exchange_rate
# 0                                  Ali Salary        1.0     5500.0      5500.0 2026-05-01  Roof Concreting  3rd Floor          73.80
# 1                                     1/2 Wood     200.0      100.0     20000.0 2026-05-01  Roof Concreting  3rd Floor          73.80
# 2                          1/2 Wood Transport        1.0      800.0       800.0 2026-05-01  Roof Concreting  3rd Floor          73.80
# 3                     2/3 Wood Rentals(25Days)     150.0        5.5     20625.0 2026-05-01  Roof Concreting  3rd Floor          73.80
# 4                          2/3 Woods Transport       1.0     1000.0      1000.0 2026-05-01  Roof Concreting  3rd Floor          73.80
# 5                                    Nail(Box)       3.0     2500.0      7500.0 2026-05-01  Roof Concreting  3rd Floor          73.80
# ...

# %%
thirdfloor_roof.to_csv('ParadiseView/out/df_thirdfloor_roof.csv', index=False)

# %%
thirdfloor_roof  = pd.read_csv('ParadiseView/out/df_thirdfloor_roof.csv')
