# %%
import pandas as pd
import numpy as np

# %%
# read a dataset into df_3rdfloor_bricks
df_3rdfloor_bricks = pd.read_csv('ParadiseView/out/df_thirdfloor_bricks.csv')

# %%
# display the dataset
df_3rdfloor_bricks
# Out:
#                   item  quantity  unit_cost  total_cost        date  \
# 0              Cement      100.0      480.0     48000.0  2025-10-14
# 1     Cement Transport     100.0       20.0      2000.0  2025-10-14
# 2      Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-14
# 3      Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-15
# 4      Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-17
# 5   Brick Molding Cost    2910.0        6.0     17460.0  2025-10-20
# 6              Cement      100.0      480.0     48000.0  2025-10-20
# 7     Cement Transport     100.0       20.0      2000.0  2025-10-20
# 8      Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-21
# 9      Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-23
# 10  Brick Molding Cost    2766.0        6.0     16600.0  2025-10-27
# 11             Cement       50.0      480.0     24000.0  2025-10-27
# 12    Cement Transport      50.0       20.0      1000.0  2025-10-27
# ...

# %%
# read a csv file
df_3rdfloor_const = pd.read_csv('ParadiseView/out/df_thirdfloor_const.csv')

# %%
df_3rdfloor_const
# Out:
#                               item  quantity  unit_cost  total_cost  \
# 0                           Cement      36.0      480.0     17280.0
# 1                Cement Transport       36.0       20.0       720.0
# 2                  Sand (10 Wheel)       1.0     8000.0      8000.0
# 3         Contractor Njaye Payment       1.0   100000.0    100000.0
# 4                  Iron Rod (12mm)     103.0      540.0     55620.0
# ..                             ...       ...        ...         ...
# 66             Material Transport        1.0      500.0       500.0
# 67  Big Pillar Mold  Rental (days)       1.0     1000.0      1000.0
# 68      Big Pillar Mold Transport        2.0      300.0       600.0
# 69        Contractor Njaye Payment       1.0    50000.0     50000.0
# 70    Residual - for Bubacarr Faye       1.0      647.0       647.0
#
#           date  sub_category   category  exchange_rate
# 0   2026-12-29  Construction  3rd Floor          74.00
# ...

# %%
df_3rdfloor_roof = pd.read_csv('ParadiseView/out/df_thirdfloor_roof.csv')

# %%
df_3rdfloor_roof
# Out:
#                                    item  quantity  unit_cost  total_cost  \
# 0                           Ali Salary        1.0     5500.0      5500.0
# 1                              1/2 Wood     200.0      100.0     20000.0
# 2                   1/2 Wood Transport        1.0      800.0       800.0
# 3              2/3 Wood Rentals(25Days)     150.0        5.5     20625.0
# 4                   2/3 Woods Transport       1.0     1000.0      1000.0
# ..                                  ...       ...        ...         ...
# 72                              Cement        3.0      455.0      1365.0
# 73                    Cement Transport        3.0       20.0        60.0
# 74  Access- no Change for Bubacarr Faye       1.0       40.0        40.0
# 75                 Rebuilding the Fence       1.0     2500.0      2500.0
# 76                Ali Watering the Roof       1.0     2000.0      2000.0
#
#           date     sub_category   category  exchange_rate
# ...

# %%
df_3rdfloor_bricks.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           15 non-null     str
#  1   quantity       15 non-null     float64
#  2   unit_cost      15 non-null     float64
#  3   total_cost     15 non-null     float64
#  4   date           15 non-null     str
#  5   sub_category   15 non-null     str
#  6   category       15 non-null     str
#  7   exchange_rate  15 non-null     float64
# dtypes: float64(4), str(4)
# memory usage: 1.1 KB

# %%
df_3rdfloor_const.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           71 non-null     str
#  1   quantity       71 non-null     float64
#  2   unit_cost      71 non-null     float64
#  3   total_cost     71 non-null     float64
#  4   date           71 non-null     str
#  5   sub_category   71 non-null     str
#  6   category       71 non-null     str
#  7   exchange_rate  71 non-null     float64
# dtypes: float64(4), str(4)
# memory usage: 4.6 KB

# %%
df_3rdfloor_roof.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           77 non-null     str
#  1   quantity       77 non-null     float64
#  2   unit_cost      77 non-null     float64
#  3   total_cost     77 non-null     float64
#  4   date           77 non-null     str
#  5   sub_category   77 non-null     str
#  6   category       77 non-null     str
#  7   exchange_rate  77 non-null     float64
# dtypes: float64(4), str(4)
# memory usage: 4.9 KB

# %%
# combine the dataset together
thirdfloor = pd.concat([df_3rdfloor_bricks, df_3rdfloor_const, df_3rdfloor_roof], ignore_index=True)

# %%
print(thirdfloor.to_string())
# Out:
#                                            item  quantity  unit_cost  total_cost        date     sub_category   category  exchange_rate
# 0                                       Cement      100.0      480.0     48000.0  2025-10-14    Brick Molding  3rd Floor          73.75
# 1                              Cement Transport     100.0       20.0      2000.0  2025-10-14    Brick Molding  3rd Floor          73.75
# 2                               Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-14    Brick Molding  3rd Floor          73.75
# 3                               Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-15    Brick Molding  3rd Floor          73.75
# 4                               Sand (10 Wheel)       1.0     8500.0      8500.0  2025-10-17    Brick Molding  3rd Floor          73.75
# 5                            Brick Molding Cost    2910.0        6.0     17460.0  2025-10-20    Brick Molding  3rd Floor          73.75
# ...

# %%
# get quick overview of the dataset
thirdfloor.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item           163 non-null    str
#  1   quantity       163 non-null    float64
#  2   unit_cost      163 non-null    float64
#  3   total_cost     163 non-null    float64
#  4   date           163 non-null    str
#  5   sub_category   163 non-null    str
#  6   category       163 non-null    str
#  7   exchange_rate  163 non-null    float64
# dtypes: float64(4), str(4)
# memory usage: 10.3 KB

# %%
# save the dataset as a csv file
thirdfloor.to_csv('Paradiseview/clean/floorThree.csv', index=False)
